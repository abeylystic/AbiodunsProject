# %%
# !pip install datapungibea
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas

import datapungibea as dpb
key = '1FD5DC35-4854-4CE8-8D43-B36065C37041'
data = dpb.data(key) 
data

# %%
# Collect county level variables
for_county_index = data.Regional(GeoFips = "COUNTY",
              LineCode = "1",
              TableName = "CAGDP9", 
              Year = "2010")
for_county_index
# Out:
#           Code GeoFips         GeoName TimePeriod  \
# 0     CAGDP9-1   01001     Autauga, AL       2010
# 1     CAGDP9-1   01003     Baldwin, AL       2010
# 2     CAGDP9-1   01005     Barbour, AL       2010
# 3     CAGDP9-1   01007        Bibb, AL       2010
# 4     CAGDP9-1   01009      Blount, AL       2010
# ...        ...     ...             ...        ...
# 3113  CAGDP9-1   56037  Sweetwater, WY       2010
# 3114  CAGDP9-1   56039       Teton, WY       2010
# 3115  CAGDP9-1   56041       Uinta, WY       2010
# 3116  CAGDP9-1   56043    Washakie, WY       2010
# 3117  CAGDP9-1   56045      Weston, WY       2010
#
#                                 CL_UNIT UNIT_MULT  DataValue NoteRef
# 0     Thousands of chained 2012 dollars         3  1,286,603     NaN
# 1     Thousands of chained 2012 dollars         3  5,381,575     NaN
# 2     Thousands of chained 2012 dollars         3    784,043     NaN
# 3     Thousands of chained 2012 dollars         3    364,023     NaN
# 4     Thousands of chained 2012 dollars         3    839,899     NaN
# ...                                 ...       ...        ...     ...
# 3113  Thousands of chained 2012 dollars         3  4,423,250     NaN
# 3114  Thousands of chained 2012 dollars         3  1,811,469     NaN
# 3115  Thousands of chained 2012 dollars         3  1,215,130     NaN
# 3116  Thousands of chained 2012 dollars         3    388,974     NaN
# 3117  Thousands of chained 2012 dollars         3    310,741     NaN
#
# [3118 rows x 8 columns]

# %%
counties = for_county_index["GeoFips"]
counties
# Out:
# 0       01001
# 1       01003
# 2       01005
# 3       01007
# 4       01009
#         ...
# 3113    56037
# 3114    56039
# 3115    56041
# 3116    56043
# 3117    56045
# Name: GeoFips, Length: 3118, dtype: object

# %%
for_GDP_components = data.Regional(GeoFips = "01001",
              LineCode = "ALL",
              TableName = "CAGDP9", 
              Year = "2010")
for_GDP_components
# Out:
#          Code GeoFips      GeoName TimePeriod  \
# 0   CAGDP9-12   01001  Autauga, AL       2010
# 1   CAGDP9-13   01001  Autauga, AL       2010
# 2   CAGDP9-25   01001  Autauga, AL       2010
# 3    CAGDP9-3   01001  Autauga, AL       2010
# 4    CAGDP9-6   01001  Autauga, AL       2010
# 5   CAGDP9-10   01001  Autauga, AL       2010
# 6   CAGDP9-11   01001  Autauga, AL       2010
# 7    CAGDP9-1   01001  Autauga, AL       2010
# 8    CAGDP9-2   01001  Autauga, AL       2010
# 9   CAGDP9-34   01001  Autauga, AL       2010
# 10  CAGDP9-35   01001  Autauga, AL       2010
# 11  CAGDP9-36   01001  Autauga, AL       2010
# 12  CAGDP9-45   01001  Autauga, AL       2010
# 13  CAGDP9-50   01001  Autauga, AL       2010
# 14  CAGDP9-51   01001  Autauga, AL       2010
# 15  CAGDP9-68   01001  Autauga, AL       2010
# 16  CAGDP9-69   01001  Autauga, AL       2010
# 17  Thousands of chained 2012 dollars         3        (D)     (D)
# 18  Thousands of chained 2012 dollars         3     40,706     NaN
# 19  Thousands of chained 2012 dollars         3      2,792     NaN
# 20  Thousands of chained 2012 dollars         3    208,744     NaN
# 21  Thousands of chained 2012 dollars         3     43,107     NaN
# 22  Thousands of chained 2012 dollars         3     20,204     NaN
# 23  Thousands of chained 2012 dollars         3        (D)     (D)
# 24  Thousands of chained 2012 dollars         3        (D)     (D)
# 25  Thousands of chained 2012 dollars         3    217,318     NaN
# 26  Thousands of chained 2012 dollars         3    218,121     NaN
# 27  Thousands of chained 2012 dollars         3    288,397     NaN
# 28  Thousands of chained 2012 dollars         3    803,805     NaN
# 29  Thousands of chained 2012 dollars         3     37,916     NaN
# 30  Thousands of chained 2012 dollars         3     47,413     NaN
# 31  Thousands of chained 2012 dollars         3    195,585     NaN
# 32  Thousands of chained 2012 dollars         3     35,382     NaN
# 33  Thousands of chained 2012 dollars         3    140,217     NaN

# %%
GDP_components = for_GDP_components[["Code", "Description"]]
GDP_components
# Out:
#          Code                                        Description
# 0   CAGDP9-12                                     Manufacturing
# 1   CAGDP9-13                       Durable goods manufacturing
# 2   CAGDP9-25                    Nondurable goods manufacturing
# 3    CAGDP9-3        Agriculture, forestry, fishing and hunting
# 4    CAGDP9-6     Mining, quarrying, and oil and gas extraction
# 5   CAGDP9-10                                         Utilities
# 6   CAGDP9-11                                      Construction
# 7    CAGDP9-1                                All industry total
# 8    CAGDP9-2                                Private industries
# 9   CAGDP9-34                                   Wholesale trade
# 10  CAGDP9-35                                      Retail trade
# 11  CAGDP9-36                    Transportation and warehousing
# 12  CAGDP9-45                                       Information
# 13  CAGDP9-50  Finance, insurance, real estate, rental, and l...
# 14  CAGDP9-51                             Finance and insurance
# 15  CAGDP9-68  Educational services, health care, and social ...
# 16  CAGDP9-69                              Educational services
# 17  CAGDP9-70                 Health care and social assistance
# 18  CAGDP9-75  Arts, entertainment, recreation, accommodation...
# 19  CAGDP9-76               Arts, entertainment, and recreation
# 20  CAGDP9-56                Real estate and rental and leasing
# 21  CAGDP9-59                Professional and business services
# 22  CAGDP9-60  Professional, scientific, and technical services
# 23  CAGDP9-64           Management of companies and enterprises
# 24  CAGDP9-65  Administrative and support and waste managemen...
# 25  CAGDP9-89                      Transportation and utilities
# 26  CAGDP9-90                     Manufacturing and information
# 27  CAGDP9-91              Private goods-producing industries 2/
# 28  CAGDP9-92           Private services-providing industries 3/
# 29  CAGDP9-79                   Accommodation and food services
# 30  CAGDP9-82  Other services (except government and governme...
# 31  CAGDP9-83             Government and government enterprises
# 32  CAGDP9-87                      Natural resources and mining
# 33  CAGDP9-88                                             Trade

# %%
# import time
# import random

# for row in GDP_components.iterrows():
#     full_code, description = row[1]
#     table_name, code = full_code.split("-")
   
#     try:
#         GDP_data_dct[description] = data.Regional(GeoFips = "COUNTY",
#               LineCode = code,
#               TableName = table_name, 
#               Year = "ALL")
#         print(full_code +": " + description + " downloaded")
#     except:
#         print(full_code +": Error downloading " + description)
#     time.sleep(10)

# %%
import os
GDP_data_dct = {}
folder1 = "Data"
folder2 = "CountyGDP"
try:
    os.mkdir(folder1)
    os.mkdir(folder1 + "/" + folder2)
except:
    try: 
        os.mkdir(folder1 + "/" + folder2)
    except:
        pass
# for key, val in GDP_data_dct.items():
#     val.to_csv(folder1 + "/" + folder2 + "/" + key.replace("/","") + ".csv")

for row in GDP_components.iterrows():
    full_code, description = row
    description = description[1]
    # somehow, space added in very last character of description
    GDP_data_dct[description] = pd.read_csv("Data/CountyGDP/" + description[:-1].replace("/","") + ".csv")
GDP_data_dct
# GDP_components
# Out:
# {'Manufacturing ':        Unnamed: 0       Code  GeoFips      GeoName  TimePeriod  \
#  0               0  CAGDP9-12     1001  Autauga, AL        2001
#  1               1  CAGDP9-12     1001  Autauga, AL        2002
#  2               2  CAGDP9-12     1001  Autauga, AL        2003
#  3               3  CAGDP9-12     1001  Autauga, AL        2004
#  4               4  CAGDP9-12     1001  Autauga, AL        2005
#  ...           ...        ...      ...          ...         ...
#  62355       62355  CAGDP9-12    56045   Weston, WY        2016
#  62356       62356  CAGDP9-12    56045   Weston, WY        2017
#  62357       62357  CAGDP9-12    56045   Weston, WY        2018
#  62358       62358  CAGDP9-12    56045   Weston, WY        2019
#  62359       62359  CAGDP9-12    56045   Weston, WY        2020
#
#                                   CL_UNIT  UNIT_MULT DataValue NoteRef
#  0      Thousands of chained 2012 dollars          3   211,416     NaN
#  1      Thousands of chained 2012 dollars          3   212,494     NaN
#  2      Thousands of chained 2012 dollars          3   182,349     NaN
#  3      Thousands of chained 2012 dollars          3   236,107     NaN
#  4      Thousands of chained 2012 dollars          3   253,936     NaN
#  ...                                  ...        ...       ...     ...
#  62355  Thousands of chained 2012 dollars          3    77,947     NaN
#  62356  Thousands of chained 2012 dollars          3   101,963     NaN
#  62357  Thousands of chained 2012 dollars          3       (D)     (D)
#  62358  Thousands of chained 2012 dollars          3       (D)     (D)
#  62359  Thousands of chained 2012 dollars          3       (D)     (D)
#
#  [62360 rows x 9 columns],
#  'Durable goods manufacturing ':        Unnamed: 0       Code  GeoFips      GeoName  TimePeriod  \
#  0               0  CAGDP9-13     1001  Autauga, AL        2001
#  1               1  CAGDP9-13     1001  Autauga, AL        2002
#  2               2  CAGDP9-13     1001  Autauga, AL        2003
#  3               3  CAGDP9-13     1001  Autauga, AL        2004
#  4               4  CAGDP9-13     1001  Autauga, AL        2005
#  ...           ...        ...      ...          ...         ...
#  62355       62355  CAGDP9-13    56045   Weston, WY        2016
#  62356       62356  CAGDP9-13    56045   Weston, WY        2017
#  62357       62357  CAGDP9-13    56045   Weston, WY        2018
#  62358       62358  CAGDP9-13    56045   Weston, WY        2019
#  62359       62359  CAGDP9-13    56045   Weston, WY        2020
#
#                                   CL_UNIT  UNIT_MULT DataValue NoteRef
#  0      Thousands of chained 2012 dollars          3       (D)     (D)
#  1      Thousands of chained 2012 dollars          3       (D)     (D)
#  2      Thousands of chained 2012 dollars          3    37,954     NaN
#  3      Thousands of chained 2012 dollars          3       (D)     (D)
#  4      Thousands of chained 2012 dollars          3       (D)     (D)
#  ...                                  ...        ...       ...     ...
#  62355  Thousands of chained 2012 dollars          3       (D)     (D)
#  62356  Thousands of chained 2012 dollars          3       (D)     (D)
#  62357  Thousands of chained 2012 dollars          3       (D)     (D)
#  62358  Thousands of chained 2012 dollars          3       (D)     (D)
#  62359  Thousands of chained 2012 dollars          3       (D)     (D)
#
#  [62360 rows x 9 columns],
#  'Nondurable goods manufacturing ':        Unnamed: 0       Code  GeoFips      GeoName  TimePeriod  \
#  0               0  CAGDP9-25     1001  Autauga, AL        2001
#  1               1  CAGDP9-25     1001  Autauga, AL        2002
#  2               2  CAGDP9-25     1001  Autauga, AL        2003
#  3               3  CAGDP9-25     1001  Autauga, AL        2004
#  4               4  CAGDP9-25     1001  Autauga, AL        2005
#  ...           ...        ...      ...          ...         ...
#  62355       62355  CAGDP9-25    56045   Weston, WY        2014
#  62356       62356  CAGDP9-25    56045   Weston, WY        2015
#  62357       62357  CAGDP9-25    56045   Weston, WY        2016
#  62358       62358  CAGDP9-25    56045   Weston, WY        2017
#  62359       62359  CAGDP9-25    56045   Weston, WY        2018
#
#                                   CL_UNIT  UNIT_MULT DataValue NoteRef
#  0      Thousands of chained 2012 dollars          3       (D)     (D)
#  1      Thousands of chained 2012 dollars          3       (D)     (D)
#  2      Thousands of chained 2012 dollars          3   143,362     NaN
#  3      Thousands of chained 2012 dollars          3       (D)     (D)
#  4      Thousands of chained 2012 dollars          3       (D)     (D)
#  ...                                  ...        ...       ...     ...
#  62355  Thousands of chained 2012 dollars          3       (D)     (D)
#  62356  Thousands of chained 2012 dollars          3       (D)     (D)
#  62357  Thousands of chained 2012 dollars          3       (D)     (D)
#  62358  Thousands of chained 2012 dollars          3       (D)     (D)
#  62359  Thousands of chained 2012 dollars          3   107,403     NaN
#
#  [62360 rows x 9 columns],
#  'Agriculture, forestry, fishing and hunting ':        Unnamed: 0      Code  GeoFips      GeoName  TimePeriod  \
#  0               0  CAGDP9
#  62359       62359  CAGDP9-88    56045   Weston, WY        2020
#
#                                   CL_UNIT  UNIT_MULT DataValue NoteRef
#  0      Thousands of chained 2012 dollars          3   116,994     NaN
#  1      Thousands of chained 2012 dollars          3   127,913     NaN
#  2      Thousands of chained 2012 dollars          3   141,218     NaN
#  3      Thousands of chained 2012 dollars          3   146,671     NaN
#  4      Thousands of chained 2012 dollars          3   151,293     NaN
#  ...                                  ...        ...       ...     ...
#  62355  Thousands of chained 2012 dollars          3       (D)     (D)
#  62356  Thousands of chained 2012 dollars          3       (D)     (D)
#  62357  Thousands of chained 2012 dollars          3    16,470     NaN
#  62358  Thousands of chained 2012 dollars          3    15,889     NaN
#  62359  Thousands of chained 2012 dollars          3    16,737     NaN
#
#  [62360 rows x 9 columns]}

# %%
os.getcwd()

# for a,b,c in os.walk("."):
#     print(a,b,c)
# Out:
# 'C:\\Users\\abiodun.idowu\\OneDrive - North Dakota University System\\Desktop\\PhD\\BEA project\\notebook_to_start'

# %%
full_df = pd.DataFrame({key[:-1]: val.set_index(["GeoFips", "TimePeriod"])["DataValue"] for key, val in GDP_data_dct.items()})
for key, val in full_df.items():
    try:
        full_df[key] = val.str.replace(
            ",","").replace("(NA)",np.NaN).replace("(D)", np.NaN).astype(float)
    except:
        continue
            
full_df
# Out:
#                     Manufacturing  Durable goods manufacturing  \
# GeoFips TimePeriod
# 1001    2001             211416.0                          NaN
#         2002             212494.0                          NaN
#         2003             182349.0                      37954.0
#         2004             236107.0                          NaN
#         2005             253936.0                          NaN
# ...                           ...                          ...
# 56045   2016              77947.0                          NaN
#         2017             101963.0                          NaN
#         2018                  NaN                          NaN
#         2019                  NaN                          NaN
#         2020                  NaN                          NaN
#
#                     Nondurable goods manufacturing  \
# GeoFips TimePeriod
# 1001    2001                                   NaN
#         2002                                   NaN
#         2003                              143362.0
#         2004                                   NaN
#         2005                                   NaN
# ...                                            ...
# 56045   2016                                   NaN
#         2017                                   NaN
#         2018                              107403.0
#         2019                              122440.0
#         2020                              134673.0
#
#                     Agriculture, forestry, fishing and hunting  \
# GeoFips TimePeriod
# 1001    2001                                           22455.0
#         2002                                           18063.0
#         2003                                           39941.0
#         2004                                           49903.0
#         2005                                           59099.0
# ...                                                        ...
# 56045   2016                                           13871.0
#         2017                                           19901.0
#         2018                                           23787.0
#         2019                                           14194.0
#         2020                                            8653.0
#
#                     Mining, quarrying, and oil and gas extraction  Utilities  \
# GeoFips TimePeriod
# 1001    2001                                               4644.0    23121.0
#         2002                                               3053.0    53320.0
#         2003                                               3696.0    57076.0
#         2004                                               5917.0    94578.0
#         2005                                               7513.0    74428.0
# ...                                                           ...        ...
# 56045   2016                                              35145.0      762.0
#         2017                                              34812.0      742.0
#         2018                                              42804.0      792.0
#         2019                                              52783.0      963.0
#         2020                                              37766.0      875.0
#
#                     Construction  All industry total  Private industries  \
# GeoFips TimePeriod
# 1001    2001            111710.0            949800.0            811076.0
#         2002             69905.0            984039.0            831984.0
#         2003             64250.0           1008032.0            847951.0
#         2004             65860.0           1170278.0            993804.0
#         2005             55006.0           1195319.0           1018262.0
# ...                          ...                 ...                 ...
# 56045   2016             11967.0            305446.0            249240.0
#         2017              8527.0            300909.0            245348.0
#         2018                 NaN            315332.0            258211.0
#         2019                 NaN            322576.0            267124.0
#         2020                 NaN            312665.0            257082.0
#
#                     Wholesale trade  ...  \
# GeoFips TimePeriod                   ...
# 1001    2001                22902.0  ...
#         2002                25425.0  ...
#         2003                29829.0  ...
#         2004                29870.0  ...
#         2005                34717.0  ...
# ...                             ...  ...
# 56045   2016                    NaN  ...
#         2017                    NaN  ...
#         2018                 1971.0  ...
#         2019                 1972.0  ...
#         2020                 2661.0  ...
#
#                     Administrative and support and waste management and remediation services  \
# GeoFips TimePeriod
# 1001    2001                                                      NaN
#         2002                                                      NaN
#         2003                                                      NaN
#         2004                                                      NaN
#         2005                                                      NaN
# ...                                                               ...
# 56045   2016                                                    655.0
#         2017                                                      NaN
#         2018                                                      NaN
#         2019                                                    756.0
#         2020                                                    908.0
#
#                     Transportation and utilities  \
# GeoFips TimePeriod
# 1001    2001                             38958.0
#         2002                             68760.0
#         2003                             72455.0
#         2004                            111059.0
#         2005                             92511.0
# ...                                          ...
# 56045   2016                             23653.0
#         2017                             15296.0
#         2018                             17451.0
#         2019                             16071.0
#         2020                             14699.0
#
#                     Manufacturing and information  \
# GeoFips TimePeriod
# 1001    2001                             215784.0
#         2002                             220916.0
#         2003                             192964.0
#         2004                             246868.0
#         2005                             265145.0
# ...                                           ...
# 56045   2016                              80729.0
#         2017                             105313.0
#         2018                                  NaN
#         2019                                  NaN
#         2020                                  NaN
#
#                     Private goods-producing industries 2  \
# GeoFips TimePeriod
# 1001    2001                                    346569.0
#         2002                                    309467.0
#         2003                                    289587.0
#         2004                                    358031.0
#         2005                                    375083.0
# ...                                                  ...
# 56045   2016                                    138913.0
#         2017                                    160891.0
#         2018                                    176341.0
#         2019                                    189801.0
#         2020                                    181709.0
#
#                     Private services-providing industries 3  \
# GeoFips TimePeriod
# 1001    2001                                       471633.0
#         2002                                       528373.0
#         2003                                       562871.0
#         2004                                       642394.0
#         2005                                       650688.0
# ...                                                     ...
# 56045   2016                                       111251.0
#         2017                                        95380.0
#         2018                                        95601.0
#         2019                                        93987.0
#         2020                                        90880.0
#
#                     Accommodation and food services  \
# GeoFips TimePeriod
# 1001    2001                                46510.0
#         2002                                45576.0
#         2003                                48870.0
#         2004                                49738.0
#         2005                                46414.0
# ...                                             ...
# 56045   2016                                 3499.0
#         2017                                    NaN
#         2018                                    NaN
#         2019                                    NaN
#         2020                                    NaN
#
#                     Other services (except government and government enterprises)  \
# GeoFips TimePeriod
# 1001    2001                                                  39040.0
#         2002                                                  43365.0
#         2003                                                  45462.0
#         2004                                                  42710.0
#         2005                                                  44318.0
# ...                                                               ...
# 56045   2016                                                   3038.0
#         2017                                                   2937.0
#         2018                                                   3178.0
#         2019                                                   3250.0
#         2020                                                   3327.0
#
#                     Government and government enterprises  \
# GeoFips TimePeriod
# 1001    2001                                     137968.0
#         2002                                     152486.0
#         2003                                     161007.0
#         2004                                     176741.0
#         2005                                     177121.0
# ...                                                   ...
# 56045   2016                                      55379.0
#         2017                                      54688.0
#         2018                                      56403.0
#         2019                                      55260.0
#         2020                                      54864.0
#
#                     Natural resources and mining     Trade
# GeoFips TimePeriod
# 1001    2001                             26803.0  116994.0
#         2002                             21183.0  127913.0
#         2003                             45092.0  141218.0
#         2004                             57065.0  146671.0
#         2005                             67930.0  151293.0
# ...                                          ...       ...
# 56045   2016                             47123.0       NaN
#         2017                             53704.0       NaN
#         2018                             65272.0   16470.0
#         2019                             64413.0   15889.0
#         2020                             44389.0   16737.0
#
# [62360 rows x 34 columns]

# %%
# full_df[["Private industries ", "Utilities "]]
list (full_df.keys())
# Out:
# ['Manufacturing',
#  'Durable goods manufacturing',
#  'Nondurable goods manufacturing',
#  'Agriculture, forestry, fishing and hunting',
#  'Mining, quarrying, and oil and gas extraction',
#  'Utilities',
#  'Construction',
#  'All industry total',
#  'Private industries',
#  'Wholesale trade',
#  'Retail trade',
#  'Transportation and warehousing',
#  'Information',
#  'Finance, insurance, real estate, rental, and leasing',
#  'Finance and insurance',
#  'Educational services, health care, and social assistance',
#  'Educational services',
#  'Health care and social assistance',
#  'Arts, entertainment, recreation, accommodation, and food services',
#  'Arts, entertainment, and recreation',
#  'Real estate and rental and leasing',
#  'Professional and business services',
#  'Professional, scientific, and technical services',
#  'Management of companies and enterprises',
#  'Administrative and support and waste management and remediation services',
#  'Transportation and utilities',
#  'Manufacturing and information',
#  'Private goods-producing industries 2',
#  'Private services-providing industries 3',
#  'Accommodation and food services',
#  'Other services (except government and government enterprises)',
#  'Government and government enterprises',
#  'Natural resources and mining',
#  'Trade']

# %%
inputs = ['All industry total',"Utilities", "Mining, quarrying, and oil and gas extraction", 'Agriculture, forestry, fishing and hunting']
for key in inputs:
    full_df[key + " 3YMA"] = full_df.reset_index().set_index(["TimePeriod"], drop = False).groupby("GeoFips")[key].rolling(3).mean().shift()
log_df = np.log(full_df)#.groupby("GeoFips").diff()
for key in inputs:
    log_df[key + " Volatility"] = (log_df[key].sub(log_df[key + " 3YMA"])).pow(2).pow(.5)
# for key in inputs:

# %% [markdown]
# - GDP
# -- layer1

# %%
import json

# %%
toc = """All industry total
1 Private industries
1.1 Agriculture, forestry, fishing and hunting
1.2 Mining, quarrying, and oil and gas extraction
1.3 Utilities
1.4 Construction
1.5 Manufacturing
1.5.1 Durable goods manufacturing
1.5.2 Nondurable goods manufacturing
1.6 Wholesale trade
1.7 Retail trade
1.8 Transportation and warehousing
1.9 Information
1.10 Finance, insurance, real estate, rental, and leasing
1.11 Finance and insurance
1.12 Real estate and rental and leasing
1.13 Professional and business services
1.14 Professional, scientific, and technical services
1.15 Management of companies and enterprises
1.16 Administrative and support and waste management and remediation services
1.17 Educational services, health care, and social assistance
1.18 Educational services
1.19 Health care and social assistance
1.20 Arts, entertainment, recreation, accommodation, and food services
1.21 Arts, entertainment, and recreation
1.22 Accommodation and food services
1.23 Other services (except government and government enterprises)
1.24 Government and government enterprises
1.25 Natural resources and mining
1.26 Trade
1.27 Transportation and utilities
1.28 Manufacturing and information
1.29 Private goods-producing industries 2/
1.30 Private services-providing industries 3/
2 """

myfile = 'GDP'

data = {myfile:{}}
for line in toc.splitlines():
    levels, title = line.split(' ', maxsplit=1)
    levels = levels.rstrip('.').split('.')
    if len(levels) == 1:
        heading = title
        data[myfile][heading] = {}
    elif len(levels) == 2:
        sub_heading = title
        data[myfile][heading][sub_heading] = []
#     if len(levels) == 3:
#         data[myfile][heading][sub_heading].append(title)

print(json.dumps(data, indent=4))
# Out:
# {
#     "GDP": {
#         "industry total": {},
#         "Private industries": {
#             "Agriculture, forestry, fishing and hunting": [],
#             "Mining, quarrying, and oil and gas extraction": [],
#             "Utilities": [],
#             "Construction": [],
#             "Manufacturing": [],
#             "Wholesale trade": [],
#             "Retail trade": [],
#             "Transportation and warehousing": [],
#             "Information": [],
#             "Finance, insurance, real estate, rental, and leasing": [],
#             "Finance and insurance": [],
#             "Real estate and rental and leasing": [],
#             "Professional and business services": [],
#             "Professional, scientific, and technical services": [],
#             "Management of companies and enterprises": [],
#             "Administrative and support and waste management and remediation services": [],
#             "Educational services, health care, and social assistance": [],
#             "Educational services": [],
#             "Health care and social assistance": [],
#             "Arts, entertainment, recreation, accommodation, and food services": [],
#             "Arts, entertainment, and recreation": [],
#             "Accommodation and food services": [],
#             "Other services (except government and government enterprises)": [],
#             "Government and government enterprises": [],
#             "Natural resources and mining": [],
#             "Trade": [],
#             "Transportation and utilities": [],
#             "Manufacturing and information": [],
#             "Private goods-producing industries 2/": [],
#             "Private services-providing industries 3/": []
#         },
#         "": {}
#     }
# }

# %%
dct = data["GDP"]
layer1 = list(dct.keys())
layer1.pop()
layer2 = []
for key in layer1:
    layer2 = layer2 + list(dct[key].keys())
layers = {0:layer1,
         1:layer2}
layers
# Out:
# {0: ['industry total', 'Private industries'],
#  1: ['Agriculture, forestry, fishing and hunting',
#   'Mining, quarrying, and oil and gas extraction',
#   'Utilities',
#   'Construction',
#   'Manufacturing',
#   'Wholesale trade',
#   'Retail trade',
#   'Transportation and warehousing',
#   'Information',
#   'Finance, insurance, real estate, rental, and leasing',
#   'Finance and insurance',
#   'Real estate and rental and leasing',
#   'Professional and business services',
#   'Professional, scientific, and technical services',
#   'Management of companies and enterprises',
#   'Administrative and support and waste management and remediation services',
#   'Educational services, health care, and social assistance',
#   'Educational services',
#   'Health care and social assistance',
#   'Arts, entertainment, recreation, accommodation, and food services',
#   'Arts, entertainment, and recreation',
#   'Accommodation and food services',
#   'Other services (except government and government enterprises)',
#   'Government and government enterprises',
#   'Natural resources and mining',
#   'Trade',
#   'Transportation and utilities',
#   'Manufacturing and information',
#   'Private goods-producing industries 2/',
#   'Private services-providing industries 3/']}

# %%
layer2
# Out:
# ['Agriculture, forestry, fishing and hunting',
#  'Mining, quarrying, and oil and gas extraction',
#  'Utilities',
#  'Construction',
#  'Manufacturing',
#  'Wholesale trade',
#  'Retail trade',
#  'Transportation and warehousing',
#  'Information',
#  'Finance, insurance, real estate, rental, and leasing',
#  'Finance and insurance',
#  'Real estate and rental and leasing',
#  'Professional and business services',
#  'Professional, scientific, and technical services',
#  'Management of companies and enterprises',
#  'Administrative and support and waste management and remediation services',
#  'Educational services, health care, and social assistance',
#  'Educational services',
#  'Health care and social assistance',
#  'Arts, entertainment, recreation, accommodation, and food services',
#  'Arts, entertainment, and recreation',
#  'Accommodation and food services',
#  'Other services (except government and government enterprises)',
#  'Government and government enterprises',
#  'Natural resources and mining',
#  'Trade',
#  'Transportation and utilities',
#  'Manufacturing and information',
#  'Private goods-producing industries 2/',
#  'Private services-providing industries 3/']

# %%
# keys = ['Agriculture, forestry, fishing and hunting',
#  'Mining, quarrying, and oil and gas extraction',
#  'Utilities',
#  'Construction',
#  'Manufacturing',
#  'Wholesale trade',
#  'Retail trade',
#  'Transportation and warehousing',
#  'Information',
#  'Finance, insurance, real estate, rental, and leasing',
#  'Finance and insurance',
#  'Professional and business services',
#  'Educational services, health care, and social assistance',
#  'Arts, entertainment, recreation, accommodation, and food services',
#  'Other services (except government and government enterprises)',
#  'Government and government enterprises']

# %%
# data2 = log_df[layer2].groupby("GeoFips").diff()
# # list(log_df.keys())

# %%
# data2

# list(data2)
# log_df
full_df
# Out:
#                     Manufacturing  Durable goods manufacturing  \
# GeoFips TimePeriod
# 1001    2001             211416.0                          NaN
#         2002             212494.0                          NaN
#         2003             182349.0                      37954.0
#         2004             236107.0                          NaN
#         2005             253936.0                          NaN
# ...                           ...                          ...
# 56045   2016              77947.0                          NaN
#         2017             101963.0                          NaN
#         2018                  NaN                          NaN
#         2019                  NaN                          NaN
#         2020                  NaN                          NaN
#
#                     Nondurable goods manufacturing  \
# GeoFips TimePeriod
# 1001    2001                                   NaN
#         2002                                   NaN
#         2003                              143362.0
#         2004                                   NaN
#         2005                                   NaN
# ...                                            ...
# 56045   2016                                   NaN
#         2017                                   NaN
#         2018                              107403.0
#         2019                              122440.0
#         2020                              134673.0
#
#                     Agriculture, forestry, fishing and hunting  \
# GeoFips TimePeriod
# 1001    2001                                           22455.0
#         2002                                           18063.0
#         2003                                           39941.0
#         2004                                           49903.0
#         2005                                           59099.0
# ...                                                        ...
# 56045   2016                                           13871.0
#         2017                                           19901.0
#         2018                                           23787.0
#         2019                                           14194.0
#         2020                                            8653.0
#
#                     Mining, quarrying, and oil and gas extraction  Utilities  \
# GeoFips TimePeriod
# 1001    2001                                               4644.0    23121.0
#         2002                                               3053.0    53320.0
#         2003                                               3696.0    57076.0
#         2004                                               5917.0    94578.0
#         2005                                               7513.0    74428.0
# ...                                                           ...        ...
# 56045   2016                                              35145.0      762.0
#         2017                                              34812.0      742.0
#         2018                                              42804.0      792.0
#         2019                                              52783.0      963.0
#         2020                                              37766.0      875.0
#
#                     Construction  All industry total  Private industries  \
# GeoFips TimePeriod
# 1001    2001            111710.0            949800.0            811076.0
#         2002             69905.0            984039.0            831984.0
#         2003             64250.0           1008032.0            847951.0
#         2004             65860.0           1170278.0            993804.0
#         2005             55006.0           1195319.0           1018262.0
# ...                          ...                 ...                 ...
# 56045   2016             11967.0            305446.0            249240.0
#         2017              8527.0            300909.0            245348.0
#         2018                 NaN            315332.0            258211.0
#         2019                 NaN            322576.0            267124.0
#         2020                 NaN            312665.0            257082.0
#
#                     Wholesale trade  ...  \
# GeoFips TimePeriod                   ...
# 1001    2001                22902.0  ...
#         2002                25425.0  ...
#         2003                29829.0  ...
#         2004                29870.0  ...
#         2005                34717.0  ...
# ...                             ...  ...
# 56045   2016                    NaN  ...
#         2017                    NaN  ...
#         2018                 1971.0  ...
#         2019                 1972.0  ...
#         2020                 2661.0  ...
#
#                     Private services-providing industries 3  \
# GeoFips TimePeriod
# 1001    2001                                       471633.0
#         2002                                       528373.0
#         2003                                       562871.0
#         2004                                       642394.0
#         2005                                       650688.0
# ...                                                     ...
# 56045   2016                                       111251.0
#         2017                                        95380.0
#         2018                                        95601.0
#         2019                                        93987.0
#         2020                                        90880.0
#
#                     Accommodation and food services  \
# GeoFips TimePeriod
# 1001    2001                                46510.0
#         2002                                45576.0
#         2003                                48870.0
#         2004                                49738.0
#         2005                                46414.0
# ...                                             ...
# 56045   2016                                 3499.0
#         2017                                    NaN
#         2018                                    NaN
#         2019                                    NaN
#         2020                                    NaN
#
#                     Other services (except government and government enterprises)  \
# GeoFips TimePeriod
# 1001    2001                                                  39040.0
#         2002                                                  43365.0
#         2003                                                  45462.0
#         2004                                                  42710.0
#         2005                                                  44318.0
# ...                                                               ...
# 56045   2016                                                   3038.0
#         2017                                                   2937.0
#         2018                                                   3178.0
#         2019                                                   3250.0
#         2020                                                   3327.0
#
#                     Government and government enterprises  \
# GeoFips TimePeriod
# 1001    2001                                     137968.0
#         2002                                     152486.0
#         2003                                     161007.0
#         2004                                     176741.0
#         2005                                     177121.0
# ...                                                   ...
# 56045   2016                                      55379.0
#         2017                                      54688.0
#         2018                                      56403.0
#         2019                                      55260.0
#         2020                                      54864.0
#
#                     Natural resources and mining     Trade  \
# GeoFips TimePeriod
# 1001    2001                             26803.0  116994.0
#         2002                             21183.0  127913.0
#         2003                             45092.0  141218.0
#         2004                             57065.0  146671.0
#         2005                             67930.0  151293.0
# ...                                          ...       ...
# 56045   2016                             47123.0       NaN
#         2017                             53704.0       NaN
#         2018                             65272.0   16470.0
#         2019                             64413.0   15889.0
#         2020                             44389.0   16737.0
#
#                     All industry total 3YMA  Utilities 3YMA  \
# GeoFips TimePeriod
# 1001    2001                            NaN             NaN
#         2002                            NaN             NaN
#         2003                            NaN             NaN
#         2004                   9.806237e+05    44505.666667
#         2005                   1.054116e+06    68324.666667
# ...                                     ...             ...
# 56045   2016                   3.051870e+05      848.666667
#         2017                   3.159413e+05      835.333333
#         2018                   3.228070e+05      809.666667
#         2019                   3.072290e+05      765.333333
#         2020                   3.129390e+05      832.333333
#
#                     Mining, quarrying, and oil and gas extraction 3YMA  \
# GeoFips TimePeriod
# 1001    2001                                                      NaN
#         2002                                                      NaN
#         2003                                                      NaN
#         2004                                              3797.666667
#         2005                                              4222.000000
# ...                                                               ...
# 56045   2016                                             31354.333333
#         2017                                             33074.666667
#         2018                                             35257.666667
#         2019                                             37587.000000
#         2020                                             43466.333333
#
#                     Agriculture, forestry, fishing and hunting 3YMA
# GeoFips TimePeriod
# 1001    2001                                                    NaN
#         2002                                                    NaN
#         2003                                                    NaN
#         2004                                           26819.666667
#         2005                                           35969.000000
# ...                                                             ...
# 56045   2016                                                    NaN
#         2017                                           18026.333333
#         2018                                           16956.333333
#         2019                                           19186.333333
#         2020                                           19294.000000
#
# [62360 rows x 38 columns]

# %%
data_dct_ips = {}
data_dct_ips['Log_Data'] = np.log(full_df)
data_dct_ips['Diff1'] = data_dct_ips['Log_Data'].groupby('GeoFips').diff()
data_dct_ips
# Out:
# {'Log_Data':                     Manufacturing  Durable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001            12.261583                          NaN
#          2002            12.266669                          NaN
#          2003            12.113678                     10.54413
#          2004            12.372040                          NaN
#          2005            12.444838                          NaN
#  ...                           ...                          ...
#  56045   2016            11.263784                          NaN
#          2017            11.532365                          NaN
#          2018                  NaN                          NaN
#          2019                  NaN                          NaN
#          2020                  NaN                          NaN
#
#                      Nondurable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                                   NaN
#          2002                                   NaN
#          2003                             11.873128
#          2004                                   NaN
#          2005                                   NaN
#  ...                                            ...
#  56045   2016                                   NaN
#          2017                                   NaN
#          2018                             11.584343
#          2019                             11.715376
#          2020                             11.810605
#
#                      Agriculture, forestry, fishing and hunting  \
#  GeoFips TimePeriod
#  1001    2001                                         10.019269
#          2002                                          9.801621
#          2003                                         10.595159
#          2004                                         10.817836
#          2005                                         10.986969
#  ...                                                        ...
#  56045   2016                                          9.537556
#          2017                                          9.898525
#          2018                                         10.076894
#          2019                                          9.560575
#          2020                                          9.065661
#
#                      Mining, quarrying, and oil and gas extraction  Utilities  \
#  GeoFips TimePeriod
#  1001    2001                                             8.443331  10.048497
#          2002                                             8.023880  10.884067
#          2003                                             8.215006  10.952139
#          2004                                             8.685585  11.457180
#          2005                                             8.924390  11.217587
#  ...                                                           ...        ...
#  56045   2016                                            10.467238   6.635947
#          2017                                            10.457717   6.609349
#          2018                                            10.664387   6.674561
#          2019                                            10.873944   6.870053
#          2020                                            10.539165   6.774224
#
#                      Construction  All industry total  Private industries  \
#  GeoFips TimePeriod
#  1001    2001           11.623662           13.764007           13.606117
#          2002           11.154892           13.799421           13.631568
#          2003           11.070537           13.823510           13.650578
#          2004           11.095287           13.972752           13.809295
#          2005           10.915198           13.993924           13.833608
#  ...                          ...                 ...                 ...
#  56045   2016            9.389908           12.629528           12.426172
#          2017            9.050993           12.614563           12.410433
#          2018                 NaN           12.661381           12.461532
#          2019                 NaN           12.684094           12.495468
#          2020                 NaN           12.652888           12.457150
#
#                      Wholesale trade  ...  \
#  GeoFips TimePeriod                   ...
#  1001    2001              10.038980  ...
#          2002              10.143488  ...
#          2003              10.303236  ...
#          2004              10.304610  ...
#          2005              10.454985  ...
#  ...                             ...  ...
#  56045   2016                    NaN  ...
#          2017                    NaN  ...
#          2018               7.586296  ...
#          2019               7.586804  ...
#          2020               7.886457  ...
#
#                      Private services-providing industries 3  \
#  GeoFips TimePeriod
#  1001    2001                                      13.063956
#          2002                                      13.177558
#          2003                                      13.240806
#          2004                                      13.372957
#          2005                                      13.385786
#  ...                                                     ...
#  56045   2016                                      11.619544
#          2017                                      11.465624
#          2018                                      11.467939
#          2019                                      11.450912
#          2020                                      11.417295
#
#                      Accommodation and food services  \
#  GeoFips TimePeriod
#  1001    2001                              10.747423
#          2002                              10.727137
#          2003                              10.796919
#          2004                              10.814525
#          2005                              10.745356
#  ...                                             ...
#  56045   2016                               8.160232
#          2017                                    NaN
#          2018                                    NaN
#          2019                                    NaN
#          2020                                    NaN
#
#                      Other services (except government and government enterprises)  \
#  GeoFips TimePeriod
#  1001    2001                                                10.572342
#          2002                                                10.677408
#          2003                                                10.724632
#          2004                                                10.662188
#          2005                                                10.699146
#  ...                                                               ...
#  56045   2016                                                 8.018955
#          2017                                                 7.985144
#          2018                                                 8.064007
#          2019                                                 8.086410
#          2020                                                 8.109826
#
#                      Government and government enterprises  \
#  GeoFips TimePeriod
#  1001    2001                                    11.834777
#          2002                                    11.934828
#          2003                                    11.989203
#          2004                                    12.082441
#          2005                                    12.084588
#  ...                                                   ...
#  56045   2016                                    10.921956
#          2017                                    10.909400
#          2018                                    10.940278
#          2019                                    10.919805
#          2020                                    10.912613
#
#                      Natural resources and mining      Trade  \
#  GeoFips TimePeriod
#  1001    2001                           10.196269  11.669878
#          2002                            9.960954  11.759106
#          2003                           10.716460  11.858060
#          2004                           10.951946  11.895947
#          2005                           11.126233  11.926974
#  ...                                          ...        ...
#  56045   2016                           10.760516        NaN
#          2017                           10.891243        NaN
#          2018                           11.086318   9.709296
#          2019                           11.073071   9.673382
#          2020                           10.700747   9.725377
#
#                      All industry total 3YMA  Utilities 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                            NaN             NaN
#          2002                            NaN             NaN
#          2003                            NaN             NaN
#          2004                      13.795944       10.703372
#          2005                      13.868213       11.132026
#  ...                                     ...             ...
#  56045   2016                      12.628680        6.743666
#          2017                      12.663312        6.727831
#          2018                      12.684810        6.696623
#          2019                      12.635349        6.640311
#          2020                      12.653764        6.724233
#
#                      Mining, quarrying, and oil and gas extraction 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                      NaN
#          2003                                                      NaN
#          2004                                                 8.242142
#          2005                                                 8.348064
#  ...                                                               ...
#  56045   2016                                                10.353108
#          2017                                                10.406523
#          2018                                                10.470438
#          2019                                                10.534414
#          2020                                                10.679742
#
#                      Agriculture, forestry, fishing and hunting 3YMA
#  GeoFips TimePeriod
#  1001    2001                                                    NaN
#          2002                                                    NaN
#          2003                                                    NaN
#          2004                                              10.196891
#          2005                                              10.490413
#  ...                                                             ...
#  56045   2016                                                    NaN
#          2017                                               9.799589
#          2018                                               9.738397
#          2019                                               9.861953
#          2020                                               9.867549
#
#  [62360 rows x 38 columns],
#  'Diff1':                     Manufacturing  Durable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                  NaN                          NaN
#          2002             0.005086                          NaN
#          2003            -0.152991                          NaN
#          2004             0.258363                          NaN
#          2005             0.072797                          NaN
#  ...                           ...                          ...
#  56045   2016            -0.465655                          NaN
#          2017             0.268581                          NaN
#          2018                  NaN                          NaN
#          2019                  NaN                          NaN
#          2020                  NaN                          NaN
#
#                      Nondurable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                                   NaN
#          2002                                   NaN
#          2003                                   NaN
#          2004                                   NaN
#          2005                                   NaN
#  ...                                            ...
#  56045   2016                                   NaN
#          2017                                   NaN
#          2018                                   NaN
#          2019                              0.131033
#          2020                              0.095229
#
#                      Agriculture, forestry, fishing and hunting  \
#  GeoFips TimePeriod
#  1001    2001                                               NaN
#          2002                                         -0.217648
#          2003                                          0.793538
#          2004                                          0.222678
#          2005                                          0.169133
#  ...                                                        ...
#  56045   2016                                         -0.209103
#          2017                                          0.360970
#          2018                                          0.178369
#          2019                                         -0.516320
#          2020                                         -0.494913
#
#                      Mining, quarrying, and oil and gas extraction  Utilities  \
#  GeoFips TimePeriod
#  1001    2001                                                  NaN        NaN
#          2002                                            -0.419451   0.835570
#          2003                                             0.191126   0.068072
#          2004                                             0.470578   0.505041
#          2005                                             0.238805  -0.239593
#  ...                                                           ...        ...
#  56045   2016                                            -0.018912  -0.193847
#          2017                                            -0.009520  -0.026597
#          2018                                             0.206669   0.065212
#          2019                                             0.209558   0.195492
#          2020                                            -0.334780  -0.095830
#
#                      Construction  All industry total  Private industries  \
#  GeoFips TimePeriod
#  1001    2001                 NaN                 NaN                 NaN
#          2002           -0.468769            0.035414            0.025451
#          2003           -0.084355            0.024090            0.019010
#          2004            0.024750            0.149241            0.158717
#          2005           -0.180089            0.021172            0.024313
#  ...                          ...                 ...                 ...
#  56045   2016           -0.249158           -0.170054           -0.217398
#          2017           -0.338915           -0.014965           -0.015739
#          2018                 NaN            0.046818            0.051099
#          2019                 NaN            0.022713            0.033936
#          2020                 NaN           -0.031206           -0.038318
#
#                      Wholesale trade  ...  \
#  GeoFips TimePeriod                   ...
#  1001    2001                    NaN  ...
#          2002               0.104509  ...
#          2003               0.159748  ...
#          2004               0.001374  ...
#          2005               0.150375  ...
#  ...                             ...  ...
#  56045   2016                    NaN  ...
#          2017                    NaN  ...
#          2018                    NaN  ...
#          2019               0.000507  ...
#          2020               0.299654  ...
#
#                      Private services-providing industries 3  \
#  GeoFips TimePeriod
#  1001    2001                                            NaN
#          2002                                       0.113601
#          2003                                       0.063248
#          2004                                       0.132151
#          2005                                       0.012828
#  ...                                                     ...
#  56045   2016                                      -0.121353
#          2017                                      -0.153920
#          2018                                       0.002314
#          2019                                      -0.017027
#          2020                                      -0.033617
#
#                      Accommodation and food services  \
#  GeoFips TimePeriod
#  1001    2001                                    NaN
#          2002                              -0.020286
#          2003                               0.069782
#          2004                               0.017606
#          2005                              -0.069168
#  ...                                             ...
#  56045   2016                                    NaN
#          2017                                    NaN
#          2018                                    NaN
#          2019                                    NaN
#          2020                                    NaN
#
#                      Other services (except government and government enterprises)  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                 0.105066
#          2003                                                 0.047224
#          2004                                                -0.062444
#          2005                                                 0.036958
#  ...                                                               ...
#  56045   2016                                                -0.131513
#          2017                                                -0.033811
#          2018                                                 0.078863
#          2019                                                 0.022403
#          2020                                                 0.023416
#
#                      Government and government enterprises  \
#  GeoFips TimePeriod
#  1001    2001                                          NaN
#          2002                                     0.100051
#          2003                                     0.054375
#          2004                                     0.093238
#          2005                                     0.002148
#  ...                                                   ...
#  56045   2016                                     0.014899
#          2017                                    -0.012556
#          2018                                     0.030878
#          2019                                    -0.020473
#          2020                                    -0.007192
#
#                      Natural resources and mining     Trade  \
#  GeoFips TimePeriod
#  1001    2001                                 NaN       NaN
#          2002                           -0.235315  0.089228
#          2003                            0.755506  0.098954
#          2004                            0.235486  0.037887
#          2005                            0.174287  0.031026
#  ...                                          ...       ...
#  56045   2016                           -0.090373       NaN
#          2017                            0.130726       NaN
#          2018                            0.195076       NaN
#          2019                           -0.013248 -0.035913
#          2020                           -0.372324  0.051995
#
#                      All industry total 3YMA  Utilities 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                            NaN             NaN
#          2002                            NaN             NaN
#          2003                            NaN             NaN
#          2004                            NaN             NaN
#          2005                       0.072269        0.428654
#  ...                                     ...             ...
#  56045   2016                       0.035981        0.060306
#          2017                       0.034632       -0.015836
#          2018                       0.021498       -0.031208
#          2019                      -0.049461       -0.056311
#          2020                       0.018415        0.083922
#
#                      Mining, quarrying, and oil and gas extraction 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                      NaN
#          2003                                                      NaN
#          2004                                                      NaN
#          2005                                                 0.105922
#  ...                                                               ...
#  56045   2016                                                 0.052770
#          2017                                                 0.053415
#          2018                                                 0.063915
#          2019                                                 0.063975
#          2020                                                 0.145328
#
#                      Agriculture, forestry, fishing and hunting 3YMA
#  GeoFips TimePeriod
#  1001    2001                                                    NaN
#          2002                                                    NaN
#          2003                                                    NaN
#          2004                                                    NaN
#          2005                                               0.293522
#  ...                                                             ...
#  56045   2016                                                    NaN
#          2017                                                    NaN
#          2018                                              -0.061192
#          2019                                               0.123557
#          2020                                               0.005596
#
#  [62360 rows x 38 columns]}

# %%
data_dct = {}
data_dct["Log Data"] = np.log(full_df).replace([np.inf, -np.inf], np.nan)
data_dct["Diff"] = data_dct["Log Data"].groupby("GeoFips").diff()#.dropna()
data_dct["2Diff"] = data_dct["Diff"].groupby("GeoFips").diff()
data_dct
# Out:
# {'Log Data':                     Manufacturing  Durable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001            12.261583                          NaN
#          2002            12.266669                          NaN
#          2003            12.113678                     10.54413
#          2004            12.372040                          NaN
#          2005            12.444838                          NaN
#  ...                           ...                          ...
#  56045   2016            11.263784                          NaN
#          2017            11.532365                          NaN
#          2018                  NaN                          NaN
#          2019                  NaN                          NaN
#          2020                  NaN                          NaN
#
#                      Nondurable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                                   NaN
#          2002                                   NaN
#          2003                             11.873128
#          2004                                   NaN
#          2005                                   NaN
#  ...                                            ...
#  56045   2016                                   NaN
#          2017                                   NaN
#          2018                             11.584343
#          2019                             11.715376
#          2020                             11.810605
#
#                      Agriculture, forestry, fishing and hunting  \
#  GeoFips TimePeriod
#  1001    2001                                         10.019269
#          2002                                          9.801621
#          2003                                         10.595159
#          2004                                         10.817836
#          2005                                         10.986969
#  ...                                                        ...
#  56045   2016                                          9.537556
#          2017                                          9.898525
#          2018                                         10.076894
#          2019                                          9.560575
#          2020                                          9.065661
#
#                      Mining, quarrying, and oil and gas extraction  Utilities  \
#  GeoFips TimePeriod
#  1001    2001                                             8.443331  10.048497
#          2002                                             8.023880  10.884067
#          2003                                             8.215006  10.952139
#          2004                                             8.685585  11.457180
#          2005                                             8.924390  11.217587
#  ...                                                           ...        ...
#  56045   2016                                            10.467238   6.635947
#          2017                                            10.457717   6.609349
#          2018                                            10.664387   6.674561
#          2019                                            10.873944   6.870053
#          2020                                            10.539165   6.774224
#
#                      Construction  All industry total  Private industries  \
#  GeoFips TimePeriod
#  1001    2001           11.623662           13.764007           13.606117
#          2002           11.154892           13.799421           13.631568
#          2003           11.070537           13.823510           13.650578
#          2004           11.095287           13.972752           13.809295
#          2005           10.915198           13.993924           13.833608
#  ...                          ...                 ...                 ...
#  56045   2016            9.389908           12.629528           12.426172
#          2017            9.050993           12.614563           12.410433
#          2018                 NaN           12.661381           12.461532
#          2019                 NaN           12.684094           12.495468
#          2020                 NaN           12.652888           12.457150
#
#                      Wholesale trade  ...  \
#  GeoFips TimePeriod                   ...
#  1001    2001              10.038980  ...
#          2002              10.143488  ...
#          2003              10.303236  ...
#          2004              10.304610  ...
#          2005              10.454985  ...
#  ...                             ...  ...
#  56045   2016                    NaN  ...
#          2017                    NaN  ...
#          2018               7.586296  ...
#          2019               7.586804  ...
#          2020               7.886457  ...
#
#                      Private services-providing industries 3  \
#  GeoFips TimePeriod
#  1001    2001                                      13.063956
#          2002                                      13.177558
#          2003                                      13.240806
#          2004                                      13.372957
#          2005                                      13.385786
#  ...                                                     ...
#  56045   2016                                      11.619544
#          2017                                      11.465624
#          2018                                      11.467939
#          2019                                      11.450912
#          2020                                      11.417295
#
#                      Accommodation and food services  \
#  GeoFips TimePeriod
#  1001    2001                              10.747423
#          2002                              10.727137
#          2003                              10.796919
#          2004                              10.814525
#          2005                              10.745356
#  ...                                             ...
#  56045   2016                               8.160232
#          2017                                    NaN
#          2018                                    NaN
#          2019                                    NaN
#          2020                                    NaN
#
#                      Other services (except government and government enterprises)  \
#  GeoFips TimePeriod
#  1001    2001                                                10.572342
#          2002                                                10.677408
#          2003                                                10.724632
#          2004                                                10.662188
#          2005                                                10.699146
#  ...                                                               ...
#  56045   2016                                                 8.018955
#          2017                                                 7.985144
#          2018                                                 8.064007
#          2019                                                 8.086410
#          2020                                                 8.109826
#
#                      Government and government enterprises  \
#  GeoFips TimePeriod
#  1001    2001                                    11.834777
#          2002                                    11.934828
#          2003                                    11.989203
#          2004                                    12.082441
#          2005                                    12.084588
#  ...                                                   ...
#  56045   2016                                    10.921956
#          2017                                    10.909400
#          2018                                    10.940278
#          2019                                    10.919805
#          2020                                    10.912613
#
#                      Natural resources and mining      Trade  \
#  GeoFips TimePeriod
#  1001    2001                           10.196269  11.669878
#          2002                            9.960954  11.759106
#          2003                           10.716460  11.858060
#          2004                           10.951946  11.895947
#          2005                           11.126233  11.926974
#  ...                                          ...        ...
#  56045   2016                           10.760516        NaN
#          2017                           10.891243        NaN
#          2018                           11.086318   9.709296
#          2019                           11.073071   9.673382
#          2020                           10.700747   9.725377
#
#                      All industry total 3YMA  Utilities 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                            NaN             NaN
#          2002                            NaN             NaN
#          2003                            NaN             NaN
#          2004                      13.795944       10.703372
#          2005                      13.868213       11.132026
#  ...                                     ...             ...
#  56045   2016                      12.628680        6.743666
#          2017                      12.663312        6.727831
#          2018                      12.684810        6.696623
#          2019                      12.635349        6.640311
#          2020                      12.653764        6.724233
#
#                      Mining, quarrying, and oil and gas extraction 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                      NaN
#          2003                                                      NaN
#          2004                                                 8.242142
#          2005                                                 8.348064
#  ...                                                               ...
#  56045   2016                                                10.353108
#          2017                                                10.406523
#          2018                                                10.470438
#          2019                                                10.534414
#          2020                                                10.679742
#
#                      Agriculture, forestry, fishing and hunting 3YMA
#  GeoFips TimePeriod
#  1001    2001                                                    NaN
#          2002                                                    NaN
#          2003                                                    NaN
#          2004                                              10.196891
#          2005                                              10.490413
#  ...                                                             ...
#  56045   2016                                                    NaN
#          2017                                               9.799589
#          2018                                               9.738397
#          2019                                               9.861953
#          2020                                               9.867549
#
#  [62360 rows x 38 columns],
#  'Diff':                     Manufacturing  Durable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                  NaN                          NaN
#          2002             0.005086                          NaN
#          2003            -0.152991                          NaN
#          2004             0.258363                          NaN
#          2005             0.072797                          NaN
#  ...                           ...                          ...
#  56045   2016            -0.465655                          NaN
#          2017             0.268581                          NaN
#          2018                  NaN                          NaN
#          2019                  NaN                          NaN
#          2020                  NaN                          NaN
#
#                      Nondurable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                                   NaN
#          2002                                   NaN
#          2003                                   NaN
#          2004                                   NaN
#          2005                                   NaN
#  ...                                            ...
#  56045   2016                                   NaN
#          2017                                   NaN
#          2018                                   NaN
#          2019                              0.131033
#          2020                              0.095229
#
#                      Agriculture, forestry, fishing and hunting  \
#  GeoFips TimePeriod
#  1001    2001                                               NaN
#          2002                                         -0.217648
#          2003                                          0.793538
#          2004                                          0.222678
#          2005                                          0.169133
#  ...                                                        ...
#  56045   2016                                         -0.209103
#          2017                                          0.360970
#          2018                                          0.178369
#          2019                                         -0.516320
#          2020                                         -0.494913
#
#                      Mining, quarrying, and oil and gas extraction  Utilities  \
#  GeoFips TimePeriod
#  1001    2001                                                  NaN        NaN
#          2002                                            -0.419451   0.835570
#          2003                                             0.191126   0.068072
#          2004                                             0.470578   0.505041
#          2005                                             0.238805  -0.239593
#  ...                                                           ...        ...
#  56045   2016                                            -0.018912  -0.193847
#          2017                                            -0.009520  -0.026597
#          2018                                             0.206669   0.065212
#          2019                                             0.209558   0.195492
#          2020                                            -0.334780  -0.095830
#
#                      Construction  All industry total  Private industries  \
#  GeoFips TimePeriod
#  1001    2001                 NaN                 NaN                 NaN
#          2002           -0.468769            0.035414            0.025451
#          2003           -0.084355            0.024090            0.019010
#          2004            0.024750            0.149241            0.158717
#          2005           -0.180089            0.021172            0.024313
#  ...                          ...                 ...                 ...
#  56045   2016           -0.249158           -0.170054           -0.217398
#          2017           -0.338915           -0.014965           -0.015739
#          2018                 NaN            0.046818            0.051099
#          2019                 NaN            0.022713            0.033936
#          2020                 NaN           -0.031206           -0.038318
#
#                      Wholesale trade  ...  \
#  GeoFips TimePeriod                   ...
#  1001    2001                    NaN  ...
#          2002               0.104509  ...
#          2003               0.159748  ...
#          2004               0.001374  ...
#          2005               0.150375  ...
#  ...                             ...  ...
#  56045   2016                    NaN  ...
#          2017                    NaN  ...
#          2018                    NaN  ...
#          2019               0.000507  ...
#          2020               0.299654  ...
#
#                      Private services-providing industries 3  \
#  GeoFips TimePeriod
#  1001    2001                                            NaN
#          2002                                       0.113601
#          2003                                       0.063248
#          2004                                       0.132151
#          2005                                       0.012828
#  ...                                                     ...
#  56045   2016                                      -0.121353
#          2017                                      -0.153920
#          2018                                       0.002314
#          2019                                      -0.017027
#          2020                                      -0.033617
#
#                      Accommodation and food services  \
#  GeoFips TimePeriod
#  1001    2001                                    NaN
#          2002                              -0.020286
#          2003                               0.069782
#          2004                               0.017606
#          2005                              -0.069168
#  ...                                             ...
#  56045   2016                                    NaN
#          2017                                    NaN
#          2018                                    NaN
#          2019                                    NaN
#          2020                                    NaN
#
#                      Other services (except government and government enterprises)  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                 0.105066
#          2003                                                 0.047224
#          2004                                                -0.062444
#          2005                                                 0.036958
#  ...                                                               ...
#  56045   2016                                                -0.131513
#          2017                                                -0.033811
#          2018                                                 0.078863
#          2019                                                 0.022403
#          2020                                                 0.023416
#
#                      Government and government enterprises  \
#  GeoFips TimePeriod
#  1001    2001                                          NaN
#          2002                                     0.100051
#          2003                                     0.054375
#          2004                                     0.093238
#          2005                                     0.002148
#  ...                                                   ...
#  56045   2016                                     0.014899
#          2017                                    -0.012556
#          2018                                     0.030878
#          2019                                    -0.020473
#          2020                                    -0.007192
#
#                      Natural resources and mining     Trade  \
#  GeoFips TimePeriod
#  1001    2001                                 NaN       NaN
#          2002                           -0.235315  0.089228
#          2003                            0.755506  0.098954
#          2004                            0.235486  0.037887
#          2005                            0.174287  0.031026
#  ...                                          ...       ...
#  56045   2016                           -0.090373       NaN
#          2017                            0.130726       NaN
#          2018                            0.195076       NaN
#          2019                           -0.013248 -0.035913
#          2020                           -0.372324  0.051995
#
#                      All industry total 3YMA  Utilities 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                            NaN             NaN
#          2002                            NaN             NaN
#          2003                            NaN             NaN
#          2004                            NaN             NaN
#          2005                       0.072269        0.428654
#  ...                                     ...             ...
#  56045   2016                       0.035981        0.060306
#          2017                       0.034632       -0.015836
#          2018                       0.021498       -0.031208
#          2019                      -0.049461       -0.056311
#          2020                       0.018415        0.083922
#
#                      Mining, quarrying, and oil and gas extraction 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                      NaN
#          2003                                                      NaN
#          2004                                                      NaN
#          2005                                                 0.105922
#  ...                                                               ...
#  56045   2016                                                 0.052770
#          2017                                                 0.053415
#          2018                                                 0.063915
#          2019                                                 0.063975
#          2020                                                 0.145328
#
#                      Agriculture, forestry, fishing and hunting 3YMA
#  GeoFips TimePeriod
#  1001    2001                                                    NaN
#          2002                                                    NaN
#          2003                                                    NaN
#          2004                                                    NaN
#          2005                                               0.293522
#  ...                                                             ...
#  56045   2016                                                    NaN
#          2017                                                    NaN
#          2018                                              -0.061192
#          2019                                               0.123557
#          2020                                               0.005596
#
#  [62360 rows x 38 columns],
#  '2Diff':                     Manufacturing  Durable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                  NaN                          NaN
#          2002                  NaN                          NaN
#          2003            -0.158077                          NaN
#          2004             0.411354                          NaN
#          2005            -0.185565                          NaN
#  ...                           ...                          ...
#  56045   2016            -1.878801                          NaN
#          2017             0.734236                          NaN
#          2018                  NaN                          NaN
#          2019                  NaN                          NaN
#          2020                  NaN                          NaN
#
#                      Nondurable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                                   NaN
#          2002                                   NaN
#          2003                                   NaN
#          2004                                   NaN
#          2005                                   NaN
#  ...                                            ...
#  56045   2016                                   NaN
#          2017                                   NaN
#          2018                                   NaN
#          2019                                   NaN
#          2020                             -0.035804
#
#                      Agriculture, forestry, fishing and hunting  \
#  GeoFips TimePeriod
#  1001    2001                                               NaN
#          2002                                               NaN
#          2003                                          1.011185
#          2004                                         -0.570860
#          2005                                         -0.053545
#  ...                                                        ...
#  56045   2016                                          0.092303
#          2017                                          0.570072
#          2018                                         -0.182600
#          2019                                         -0.694689
#          2020                                          0.021407
#
#                      Mining, quarrying, and oil and gas extraction  Utilities  \
#  GeoFips TimePeriod
#  1001    2001                                                  NaN        NaN
#          2002                                                  NaN        NaN
#          2003                                             0.610578  -0.767498
#          2004                                             0.279452   0.436969
#          2005                                            -0.231773  -0.744634
#  ...                                                           ...        ...
#  56045   2016                                            -0.255754  -0.315557
#          2017                                             0.009392   0.167250
#          2018                                             0.216190   0.091809
#          2019                                             0.002888   0.130280
#          2020                                            -0.544338  -0.291322
#
#                      Construction  All industry total  Private industries  \
#  GeoFips TimePeriod
#  1001    2001                 NaN                 NaN                 NaN
#          2002                 NaN                 NaN                 NaN
#          2003            0.384414           -0.011324           -0.006442
#          2004            0.109105            0.125152            0.139708
#          2005           -0.204839           -0.128070           -0.134405
#  ...                          ...                 ...                 ...
#  56045   2016           -0.114219           -0.425977           -0.539403
#          2017           -0.089757            0.155088            0.201659
#          2018                 NaN            0.061783            0.066838
#          2019                 NaN           -0.024105           -0.017164
#          2020                 NaN           -0.053919           -0.072254
#
#                      Wholesale trade  ...  \
#  GeoFips TimePeriod                   ...
#  1001    2001                    NaN  ...
#          2002                    NaN  ...
#          2003               0.055239  ...
#          2004              -0.158375  ...
#          2005               0.149001  ...
#  ...                             ...  ...
#  56045   2016                    NaN  ...
#          2017                    NaN  ...
#          2018                    NaN  ...
#          2019                    NaN  ...
#          2020               0.299147  ...
#
#                      Private services-providing industries 3  \
#  GeoFips TimePeriod
#  1001    2001                                            NaN
#          2002                                            NaN
#          2003                                      -0.050353
#          2004                                       0.068903
#          2005                                      -0.119323
#  ...                                                     ...
#  56045   2016                                      -0.177946
#          2017                                      -0.032567
#          2018                                       0.156234
#          2019                                      -0.019341
#          2020                                      -0.016590
#
#                      Accommodation and food services  \
#  GeoFips TimePeriod
#  1001    2001                                    NaN
#          2002                                    NaN
#          2003                               0.090069
#          2004                              -0.052177
#          2005                              -0.086774
#  ...                                             ...
#  56045   2016                                    NaN
#          2017                                    NaN
#          2018                                    NaN
#          2019                                    NaN
#          2020                                    NaN
#
#                      Other services (except government and government enterprises)  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                      NaN
#          2003                                                -0.057842
#          2004                                                -0.109668
#          2005                                                 0.099402
#  ...                                                               ...
#  56045   2016                                                -0.000257
#          2017                                                 0.097702
#          2018                                                 0.112674
#          2019                                                -0.056460
#          2020                                                 0.001013
#
#                      Government and government enterprises  \
#  GeoFips TimePeriod
#  1001    2001                                          NaN
#          2002                                          NaN
#          2003                                    -0.045676
#          2004                                     0.038862
#          2005                                    -0.091090
#  ...                                                   ...
#  56045   2016                                     0.033638
#          2017                                    -0.027456
#          2018                                     0.043434
#          2019                                    -0.051351
#          2020                                     0.013281
#
#                      Natural resources and mining     Trade  \
#  GeoFips TimePeriod
#  1001    2001                                 NaN       NaN
#          2002                                 NaN       NaN
#          2003                            0.990821  0.009727
#          2004                           -0.520020 -0.061067
#          2005                           -0.061199 -0.006861
#  ...                                          ...       ...
#  56045   2016                           -0.107936       NaN
#          2017                            0.221099       NaN
#          2018                            0.064349       NaN
#          2019                           -0.208323       NaN
#          2020                           -0.359076  0.087908
#
#                      All industry total 3YMA  Utilities 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                            NaN             NaN
#          2002                            NaN             NaN
#          2003                            NaN             NaN
#          2004                            NaN             NaN
#          2005                            NaN             NaN
#  ...                                     ...             ...
#  56045   2016                       0.047819        0.329673
#          2017                      -0.001349       -0.076141
#          2018                      -0.013134       -0.015373
#          2019                      -0.070959       -0.025103
#          2020                       0.067876        0.140233
#
#                      Mining, quarrying, and oil and gas extraction 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                      NaN
#          2003                                                      NaN
#          2004                                                      NaN
#          2005                                                      NaN
#  ...                                                               ...
#  56045   2016                                                 0.089529
#          2017                                                 0.000645
#          2018                                                 0.010500
#          2019                                                 0.000060
#          2020                                                 0.081353
#
#                      Agriculture, forestry, fishing and hunting 3YMA
#  GeoFips TimePeriod
#  1001    2001                                                    NaN
#          2002                                                    NaN
#          2003                                                    NaN
#          2004                                                    NaN
#          2005                                                    NaN
#  ...                                                             ...
#  56045   2016                                                    NaN
#          2017                                                    NaN
#          2018                                                    NaN
#          2019                                               0.184749
#          2020                                              -0.117961
#
#  [62360 rows x 38 columns]}

# %% [markdown]
# write if the variables are sub-components

# %%
# remove duplicate first index column
def reset_index(df):
    name1,name2 = list(df.index.names)[1:]
    ix1, ix2 =df.index.get_level_values(1), df.index.get_level_values(2) 
    df[name1] = ix1
    df[name2] = ix2
    df.reset_index(drop=True, inplace = True)
    df.set_index(["GeoFips", "TimePeriod"], inplace = True)
    
ips_keys = ['Agriculture, forestry, fishing and hunting',
 'Mining, quarrying, and oil and gas extraction',
 'Utilities',
 "All industry total"]
ips_df = data_dct["Diff"][ips_keys]
ips_df = ips_df[ips_df.index.get_level_values("TimePeriod")>2001]
ips_df = ips_df.groupby("GeoFips").apply(lambda x: x.dropna(axis = 1)).dropna()
ips_df
# Out:
#                     Agriculture, forestry, fishing and hunting  \
# GeoFips TimePeriod
# 1001    2002                                         -0.217648
#         2003                                          0.793538
#         2004                                          0.222678
#         2005                                          0.169133
#         2006                                          0.176881
# ...                                                        ...
# 56041   2016                                          0.016426
#         2017                                         -0.156890
#         2018                                          0.231567
#         2019                                          0.839924
#         2020                                          0.274166
#
#                     Mining, quarrying, and oil and gas extraction  Utilities  \
# GeoFips TimePeriod
# 1001    2002                                            -0.419451   0.835570
#         2003                                             0.191126   0.068072
#         2004                                             0.470578   0.505041
#         2005                                             0.238805  -0.239593
#         2006                                             0.342614   0.436516
# ...                                                           ...        ...
# 56041   2016                                            -0.081156   0.211513
#         2017                                            -0.158175   0.004846
#         2018                                            -0.207405  -0.179435
#         2019                                            -0.452308   0.279935
#         2020                                            -0.747581  -0.020288
#
#                     All industry total
# GeoFips TimePeriod
# 1001    2002                  0.035414
#         2003                  0.024090
#         2004                  0.149241
#         2005                  0.021172
#         2006                  0.066174
# ...                                ...
# 56041   2016                 -0.006544
#         2017                 -0.023853
#         2018                 -0.037587
#         2019                 -0.024081
#         2020                 -0.108416
#
# [11343 rows x 4 columns]

# %%
# ips_df2 = ips_df.groupby("GeoFips").apply(lambda x: x.iloc[x.isnull().values.argmin():])
# reset_index(ips_df2)
# ips_df2 = ips_df2.groupby("GeoFips").apply(lambda x: x.iloc[:x.isnull().values.argmax()])
# reset_index(ips_df2)
# for i in range(3):
#     ips_df2 = ips_df2.groupby("GeoFips").apply(lambda x: x.iloc[x.isnull().values.argmin()+1:])
#     reset_index(ips_df2)
# # .values.argmin()

# %%
# ips_df.iloc[
# data.iloc[:data.A.isnull().values.argmax()]
# ips_df2 = ips_df.groupby("GeoFips").apply(lambda x: x.iloc[x.isnull().values.argmin()+1:])
# ips_df2.groupby("GeoFips").apply(lambda x: x.iloc[:x.isnull().values.argmax()])

# %%
from statsmodels.tsa.stattools import adfuller

def adfuller_table(df):
    df_results = {}
    for key, vector in df.items():
        dftest = adfuller(vector, maxlag = 4, regression = 'c')
        df_results[key] = pd.Series(dftest[0:4], index = ['t-stat', 'p-value', 
                                                         '#Lags Used', 'Number of Observations Used'])
    return pd.DataFrame(df_results).round(2)

# %%
# adfuller_table(data_dct['Diff'])

# %%
import statistics
import math
data = data_dct_ips['Diff1'].replace([np.inf, -np.inf]).fillna(0)
data
data_ips = {}
# data_ips = data.reset_index()
data_ips['Diff']= data
data_ips
# Out:
# {'Diff':                     Manufacturing  Durable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001             0.000000                          0.0
#          2002             0.005086                          0.0
#          2003            -0.152991                          0.0
#          2004             0.258363                          0.0
#          2005             0.072797                          0.0
#  ...                           ...                          ...
#  56045   2016            -0.465655                          0.0
#          2017             0.268581                          0.0
#          2018             0.000000                          0.0
#          2019             0.000000                          0.0
#          2020             0.000000                          0.0
#
#                      Nondurable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                              0.000000
#          2002                              0.000000
#          2003                              0.000000
#          2004                              0.000000
#          2005                              0.000000
#  ...                                            ...
#  56045   2016                              0.000000
#          2017                              0.000000
#          2018                              0.000000
#          2019                              0.131033
#          2020                              0.095229
#
#                      Agriculture, forestry, fishing and hunting  \
#  GeoFips TimePeriod
#  1001    2001                                          0.000000
#          2002                                         -0.217648
#          2003                                          0.793538
#          2004                                          0.222678
#          2005                                          0.169133
#  ...                                                        ...
#  56045   2016                                         -0.209103
#          2017                                          0.360970
#          2018                                          0.178369
#          2019                                         -0.516320
#          2020                                         -0.494913
#
#                      Mining, quarrying, and oil and gas extraction  Utilities  \
#  GeoFips TimePeriod
#  1001    2001                                             0.000000   0.000000
#          2002                                            -0.419451   0.835570
#          2003                                             0.191126   0.068072
#          2004                                             0.470578   0.505041
#          2005                                             0.238805  -0.239593
#  ...                                                           ...        ...
#  56045   2016                                            -0.018912  -0.193847
#          2017                                            -0.009520  -0.026597
#          2018                                             0.206669   0.065212
#          2019                                             0.209558   0.195492
#          2020                                            -0.334780  -0.095830
#
#                      Construction  All industry total  Private industries  \
#  GeoFips TimePeriod
#  1001    2001            0.000000            0.000000            0.000000
#          2002           -0.468769            0.035414            0.025451
#          2003           -0.084355            0.024090            0.019010
#          2004            0.024750            0.149241            0.158717
#          2005           -0.180089            0.021172            0.024313
#  ...                          ...                 ...                 ...
#  56045   2016           -0.249158           -0.170054           -0.217398
#          2017           -0.338915           -0.014965           -0.015739
#          2018            0.000000            0.046818            0.051099
#          2019            0.000000            0.022713            0.033936
#          2020            0.000000           -0.031206           -0.038318
#
#                      Wholesale trade  ...  \
#  GeoFips TimePeriod                   ...
#  1001    2001               0.000000  ...
#          2002               0.104509  ...
#          2003               0.159748  ...
#          2004               0.001374  ...
#          2005               0.150375  ...
#  ...                             ...  ...
#  56045   2016               0.000000  ...
#          2017               0.000000  ...
#          2018               0.000000  ...
#          2019               0.000507  ...
#          2020               0.299654  ...
#
#                      Private services-providing industries 3  \
#  GeoFips TimePeriod
#  1001    2001                                       0.000000
#          2002                                       0.113601
#          2003                                       0.063248
#          2004                                       0.132151
#          2005                                       0.012828
#  ...                                                     ...
#  56045   2016                                      -0.121353
#          2017                                      -0.153920
#          2018                                       0.002314
#          2019                                      -0.017027
#          2020                                      -0.033617
#
#                      Accommodation and food services  \
#  GeoFips TimePeriod
#  1001    2001                               0.000000
#          2002                              -0.020286
#          2003                               0.069782
#          2004                               0.017606
#          2005                              -0.069168
#  ...                                             ...
#  56045   2016                               0.000000
#          2017                               0.000000
#          2018                               0.000000
#          2019                               0.000000
#          2020                               0.000000
#
#                      Other services (except government and government enterprises)  \
#  GeoFips TimePeriod
#  1001    2001                                                 0.000000
#          2002                                                 0.105066
#          2003                                                 0.047224
#          2004                                                -0.062444
#          2005                                                 0.036958
#  ...                                                               ...
#  56045   2016                                                -0.131513
#          2017                                                -0.033811
#          2018                                                 0.078863
#          2019                                                 0.022403
#          2020                                                 0.023416
#
#                      Government and government enterprises  \
#  GeoFips TimePeriod
#  1001    2001                                     0.000000
#          2002                                     0.100051
#          2003                                     0.054375
#          2004                                     0.093238
#          2005                                     0.002148
#  ...                                                   ...
#  56045   2016                                     0.014899
#          2017                                    -0.012556
#          2018                                     0.030878
#          2019                                    -0.020473
#          2020                                    -0.007192
#
#                      Natural resources and mining     Trade  \
#  GeoFips TimePeriod
#  1001    2001                            0.000000  0.000000
#          2002                           -0.235315  0.089228
#          2003                            0.755506  0.098954
#          2004                            0.235486  0.037887
#          2005                            0.174287  0.031026
#  ...                                          ...       ...
#  56045   2016                           -0.090373  0.000000
#          2017                            0.130726  0.000000
#          2018                            0.195076  0.000000
#          2019                           -0.013248 -0.035913
#          2020                           -0.372324  0.051995
#
#                      All industry total 3YMA  Utilities 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                       0.000000        0.000000
#          2002                       0.000000        0.000000
#          2003                       0.000000        0.000000
#          2004                       0.000000        0.000000
#          2005                       0.072269        0.428654
#  ...                                     ...             ...
#  56045   2016                       0.035981        0.060306
#          2017                       0.034632       -0.015836
#          2018                       0.021498       -0.031208
#          2019                      -0.049461       -0.056311
#          2020                       0.018415        0.083922
#
#                      Mining, quarrying, and oil and gas extraction 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                                                 0.000000
#          2002                                                 0.000000
#          2003                                                 0.000000
#          2004                                                 0.000000
#          2005                                                 0.105922
#  ...                                                               ...
#  56045   2016                                                 0.052770
#          2017                                                 0.053415
#          2018                                                 0.063915
#          2019                                                 0.063975
#          2020                                                 0.145328
#
#                      Agriculture, forestry, fishing and hunting 3YMA
#  GeoFips TimePeriod
#  1001    2001                                               0.000000
#          2002                                               0.000000
#          2003                                               0.000000
#          2004                                               0.000000
#          2005                                               0.293522
#  ...                                                             ...
#  56045   2016                                               0.000000
#          2017                                               0.000000
#          2018                                              -0.061192
#          2019                                               0.123557
#          2020                                               0.005596
#
#  [62360 rows x 38 columns]}

# %%
# data_ips_var = ['GeoFips', 'TimePeriod', 'All industry total']
# data_ips_t = data_ips[data_ips_var]
# data_ips_t
# data_ips_t['All industry total'].replace(to_replace = 0, value = 1, inplace=True)

# %%
# data_test = pd.read_csv('ips.csv')
# data_test

# %% [markdown]
# # IPS Test

# %%
def ips_test(data, Firm, Time):
    df = data.set_index([Firm, Time])
    df2 = data.set_index([Time, Firm])
    firms = list(data[Firm].unique())
    times = list(data[Time].unique())
    data = data.set_index(Firm)
    N = len(firms)
    dict_temp = {}

    for firm in firms:
        lag_val = []
        val_diff = []
        lag_val_diff = []
        for i in data[Time].loc[firm]:
            cur_val = i
            if lag_val == []:
                pass
            else:
                val_diff = cur_val - lag_val
            if lag_val_diff == []:
                pass
            else:
                if val_diff != lag_val_diff:
                    raise ValueError("The data does not have constant time variation")
            lag_val = i
            lag_val_diff = val_diff

        for key in df:
            total_temp_stat = 0
            for firm in firms:
                temp_df = data[[key]].loc[firm]
                temp_stat = adfuller(temp_df, maxlag = 0, regression = 'ct')[0]
                total_temp_stat += temp_stat
                t_bar = (1/N)*total_temp_stat
                dict_temp[key] = t_bar

    df_temp = pd.DataFrame([dict_temp]).T
    df_temp.columns = ['Test Stat']
    return df_temp

# %% [markdown]
# Download interest rate data (divisia), and average it annually

# %%
divisia = pd.read_excel("https://centerforfinancialstability.org/amfm/Divisia.xlsx", 
                        sheet_name = "Broad", header  =1, index_col = "Date")

index = divisia.index
keys = divisia.keys()
divisia = divisia.resample("A").mean().rename(columns={keys[0]: "M4",
                                                       keys[2]:"M4 Interest Rate"})
year_lst = [i for i in range(1966, 2023)]
divisia = divisia[["M4", "M4 Interest Rate"]].reset_index()
divisia["TimePeriod"] = year_lst
divisia = divisia.set_index("TimePeriod").drop(columns = "Date")
divisia.head()
# Out:
#                     M4  M4 Interest Rate
# TimePeriod
# 1966        103.844756          0.033092
# 1967        111.127648          0.036325
# 1968        116.671638          0.042464
# 1969        119.176420          0.042731
# 1970        130.440949          0.034850

# %%
# data["Level"]["$r_{M4}$"] = divisia["M4 Interest Rate"]

# %% [markdown]
# Add/join the interest rates to the original dataframe

# %%
data_df = full_df.copy().reset_index().set_index("TimePeriod")
data_df = data_df.join(divisia).reset_index()     
data_df = data_df.set_index(["GeoFips", "TimePeriod"])    
data_df = data_df.sort_index()
data_df
# Out:
#                     Manufacturing  Durable goods manufacturing  \
# GeoFips TimePeriod
# 1001    2001             211416.0                          NaN
#         2002             212494.0                          NaN
#         2003             182349.0                      37954.0
#         2004             236107.0                          NaN
#         2005             253936.0                          NaN
# ...                           ...                          ...
# 56045   2016              77947.0                          NaN
#         2017             101963.0                          NaN
#         2018                  NaN                          NaN
#         2019                  NaN                          NaN
#         2020                  NaN                          NaN
#
#                     Nondurable goods manufacturing  \
# GeoFips TimePeriod
# 1001    2001                                   NaN
#         2002                                   NaN
#         2003                              143362.0
#         2004                                   NaN
#         2005                                   NaN
# ...                                            ...
# 56045   2016                                   NaN
#         2017                                   NaN
#         2018                              107403.0
#         2019                              122440.0
#         2020                              134673.0
#
#                     Agriculture, forestry, fishing and hunting  \
# GeoFips TimePeriod
# 1001    2001                                           22455.0
#         2002                                           18063.0
#         2003                                           39941.0
#         2004                                           49903.0
#         2005                                           59099.0
# ...                                                        ...
# 56045   2016                                           13871.0
#         2017                                           19901.0
#         2018                                           23787.0
#         2019                                           14194.0
#         2020                                            8653.0
#
#                     Mining, quarrying, and oil and gas extraction  Utilities  \
# GeoFips TimePeriod
# 1001    2001                                               4644.0    23121.0
#         2002                                               3053.0    53320.0
#         2003                                               3696.0    57076.0
#         2004                                               5917.0    94578.0
#         2005                                               7513.0    74428.0
# ...                                                           ...        ...
# 56045   2016                                              35145.0      762.0
#         2017                                              34812.0      742.0
#         2018                                              42804.0      792.0
#         2019                                              52783.0      963.0
#         2020                                              37766.0      875.0
#
#                     Construction  All industry total  Private industries  \
# GeoFips TimePeriod
# 1001    2001            111710.0            949800.0            811076.0
#         2002             69905.0            984039.0            831984.0
#         2003             64250.0           1008032.0            847951.0
#         2004             65860.0           1170278.0            993804.0
#         2005             55006.0           1195319.0           1018262.0
# ...                          ...                 ...                 ...
# 56045   2016             11967.0            305446.0            249240.0
#         2017              8527.0            300909.0            245348.0
#         2018                 NaN            315332.0            258211.0
#         2019                 NaN            322576.0            267124.0
#         2020                 NaN            312665.0            257082.0
#
#                     Wholesale trade  ...  \
# GeoFips TimePeriod                   ...
# 1001    2001                22902.0  ...
#         2002                25425.0  ...
#         2003                29829.0  ...
#         2004                29870.0  ...
#         2005                34717.0  ...
# ...                             ...  ...
# 56045   2016                    NaN  ...
#         2017                    NaN  ...
#         2018                 1971.0  ...
#         2019                 1972.0  ...
#         2020                 2661.0  ...
#
#                     Other services (except government and government enterprises)  \
# GeoFips TimePeriod
# 1001    2001                                                  39040.0
#         2002                                                  43365.0
#         2003                                                  45462.0
#         2004                                                  42710.0
#         2005                                                  44318.0
# ...                                                               ...
# 56045   2016                                                   3038.0
#         2017                                                   2937.0
#         2018                                                   3178.0
#         2019                                                   3250.0
#         2020                                                   3327.0
#
#                     Government and government enterprises  \
# GeoFips TimePeriod
# 1001    2001                                     137968.0
#         2002                                     152486.0
#         2003                                     161007.0
#         2004                                     176741.0
#         2005                                     177121.0
# ...                                                   ...
# 56045   2016                                      55379.0
#         2017                                      54688.0
#         2018                                      56403.0
#         2019                                      55260.0
#         2020                                      54864.0
#
#                     Natural resources and mining     Trade  \
# GeoFips TimePeriod
# 1001    2001                             26803.0  116994.0
#         2002                             21183.0  127913.0
#         2003                             45092.0  141218.0
#         2004                             57065.0  146671.0
#         2005                             67930.0  151293.0
# ...                                          ...       ...
# 56045   2016                             47123.0       NaN
#         2017                             53704.0       NaN
#         2018                             65272.0   16470.0
#         2019                             64413.0   15889.0
#         2020                             44389.0   16737.0
#
#                     All industry total 3YMA  Utilities 3YMA  \
# GeoFips TimePeriod
# 1001    2001                            NaN             NaN
#         2002                            NaN             NaN
#         2003                            NaN             NaN
#         2004                   9.806237e+05    44505.666667
#         2005                   1.054116e+06    68324.666667
# ...                                     ...             ...
# 56045   2016                   3.051870e+05      848.666667
#         2017                   3.159413e+05      835.333333
#         2018                   3.228070e+05      809.666667
#         2019                   3.072290e+05      765.333333
#         2020                   3.129390e+05      832.333333
#
#                     Mining, quarrying, and oil and gas extraction 3YMA  \
# GeoFips TimePeriod
# 1001    2001                                                      NaN
#         2002                                                      NaN
#         2003                                                      NaN
#         2004                                              3797.666667
#         2005                                              4222.000000
# ...                                                               ...
# 56045   2016                                             31354.333333
#         2017                                             33074.666667
#         2018                                             35257.666667
#         2019                                             37587.000000
#         2020                                             43466.333333
#
#                     Agriculture, forestry, fishing and hunting 3YMA  \
# GeoFips TimePeriod
# 1001    2001                                                    NaN
#         2002                                                    NaN
#         2003                                                    NaN
#         2004                                           26819.666667
#         2005                                           35969.000000
# ...                                                             ...
# 56045   2016                                                    NaN
#         2017                                           18026.333333
#         2018                                           16956.333333
#         2019                                           19186.333333
#         2020                                           19294.000000
#
#                              M4  M4 Interest Rate
# GeoFips TimePeriod
# 1001    2001         842.669405          0.012311
#         2002         890.952161          0.007415
#         2003         935.468333          0.008946
#         2004         987.636582          0.020889
#         2005        1044.732175          0.032386
# ...                         ...               ...
# 56045   2016        1472.650174          0.003105
#         2017        1538.082422          0.006835
#         2018        1620.728649          0.008433
#         2019        1996.594570          0.002033
#         2020        2200.431987          0.000516
#
# [62360 rows x 40 columns]

# %% [markdown]
# Convert variables to rates and differenced data

# %%
data_dct1 = {}
data_dct1["Log Data"] = np.log(data_df).replace([np.inf, -np.inf], np.nan)
data_dct1["Diff"] = data_dct1["Log Data"].groupby("GeoFips").diff()#.dropna()
#data_dct1["2Diff"] = data_dct1["Diff"].groupby("GeoFips").diff()
data_dct1
# Out:
# {'Log Data':                     Manufacturing  Durable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001            12.261583                          NaN
#          2002            12.266669                          NaN
#          2003            12.113678                     10.54413
#          2004            12.372040                          NaN
#          2005            12.444838                          NaN
#  ...                           ...                          ...
#  56045   2016            11.263784                          NaN
#          2017            11.532365                          NaN
#          2018                  NaN                          NaN
#          2019                  NaN                          NaN
#          2020                  NaN                          NaN
#
#                      Nondurable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                                   NaN
#          2002                                   NaN
#          2003                             11.873128
#          2004                                   NaN
#          2005                                   NaN
#  ...                                            ...
#  56045   2016                                   NaN
#          2017                                   NaN
#          2018                             11.584343
#          2019                             11.715376
#          2020                             11.810605
#
#                      Agriculture, forestry, fishing and hunting  \
#  GeoFips TimePeriod
#  1001    2001                                         10.019269
#          2002                                          9.801621
#          2003                                         10.595159
#          2004                                         10.817836
#          2005                                         10.986969
#  ...                                                        ...
#  56045   2016                                          9.537556
#          2017                                          9.898525
#          2018                                         10.076894
#          2019                                          9.560575
#          2020                                          9.065661
#
#                      Mining, quarrying, and oil and gas extraction  Utilities  \
#  GeoFips TimePeriod
#  1001    2001                                             8.443331  10.048497
#          2002                                             8.023880  10.884067
#          2003                                             8.215006  10.952139
#          2004                                             8.685585  11.457180
#          2005                                             8.924390  11.217587
#  ...                                                           ...        ...
#  56045   2016                                            10.467238   6.635947
#          2017                                            10.457717   6.609349
#          2018                                            10.664387   6.674561
#          2019                                            10.873944   6.870053
#          2020                                            10.539165   6.774224
#
#                      Construction  All industry total  Private industries  \
#  GeoFips TimePeriod
#  1001    2001           11.623662           13.764007           13.606117
#          2002           11.154892           13.799421           13.631568
#          2003           11.070537           13.823510           13.650578
#          2004           11.095287           13.972752           13.809295
#          2005           10.915198           13.993924           13.833608
#  ...                          ...                 ...                 ...
#  56045   2016            9.389908           12.629528           12.426172
#          2017            9.050993           12.614563           12.410433
#          2018                 NaN           12.661381           12.461532
#          2019                 NaN           12.684094           12.495468
#          2020                 NaN           12.652888           12.457150
#
#                      Wholesale trade  ...  \
#  GeoFips TimePeriod                   ...
#  1001    2001              10.038980  ...
#          2002              10.143488  ...
#          2003              10.303236  ...
#          2004              10.304610  ...
#          2005              10.454985  ...
#  ...                             ...  ...
#  56045   2016                    NaN  ...
#          2017                    NaN  ...
#          2018               7.586296  ...
#          2019               7.586804  ...
#          2020               7.886457  ...
#
#                      Other services (except government and government enterprises)  \
#  GeoFips TimePeriod
#  1001    2001                                                10.572342
#          2002                                                10.677408
#          2003                                                10.724632
#          2004                                                10.662188
#          2005                                                10.699146
#  ...                                                               ...
#  56045   2016                                                 8.018955
#          2017                                                 7.985144
#          2018                                                 8.064007
#          2019                                                 8.086410
#          2020                                                 8.109826
#
#                      Government and government enterprises  \
#  GeoFips TimePeriod
#  1001    2001                                    11.834777
#          2002                                    11.934828
#          2003                                    11.989203
#          2004                                    12.082441
#          2005                                    12.084588
#  ...                                                   ...
#  56045   2016                                    10.921956
#          2017                                    10.909400
#          2018                                    10.940278
#          2019                                    10.919805
#          2020                                    10.912613
#
#                      Natural resources and mining      Trade  \
#  GeoFips TimePeriod
#  1001    2001                           10.196269  11.669878
#          2002                            9.960954  11.759106
#          2003                           10.716460  11.858060
#          2004                           10.951946  11.895947
#          2005                           11.126233  11.926974
#  ...                                          ...        ...
#  56045   2016                           10.760516        NaN
#          2017                           10.891243        NaN
#          2018                           11.086318   9.709296
#          2019                           11.073071   9.673382
#          2020                           10.700747   9.725377
#
#                      All industry total 3YMA  Utilities 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                            NaN             NaN
#          2002                            NaN             NaN
#          2003                            NaN             NaN
#          2004                      13.795944       10.703372
#          2005                      13.868213       11.132026
#  ...                                     ...             ...
#  56045   2016                      12.628680        6.743666
#          2017                      12.663312        6.727831
#          2018                      12.684810        6.696623
#          2019                      12.635349        6.640311
#          2020                      12.653764        6.724233
#
#                      Mining, quarrying, and oil and gas extraction 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                      NaN
#          2003                                                      NaN
#          2004                                                 8.242142
#          2005                                                 8.348064
#  ...                                                               ...
#  56045   2016                                                10.353108
#          2017                                                10.406523
#          2018                                                10.470438
#          2019                                                10.534414
#          2020                                                10.679742
#
#                      Agriculture, forestry, fishing and hunting 3YMA        M4  \
#  GeoFips TimePeriod
#  1001    2001                                                    NaN  6.736575
#          2002                                                    NaN  6.792291
#          2003                                                    NaN  6.841047
#          2004                                              10.196891  6.895315
#          2005                                              10.490413  6.951516
#  ...                                                             ...       ...
#  56045   2016                                                    NaN  7.294819
#          2017                                               9.799589  7.338292
#          2018                                               9.738397  7.390631
#          2019                                               9.861953  7.599198
#          2020                                               9.867549  7.696409
#
#                      M4 Interest Rate
#  GeoFips TimePeriod
#  1001    2001               -4.397281
#          2002               -4.904205
#          2003               -4.716604
#          2004               -3.868539
#          2005               -3.430040
#  ...                              ...
#  56045   2016               -5.774862
#          2017               -4.985694
#          2018               -4.775658
#          2019               -6.198190
#          2020               -7.569088
#
#  [62360 rows x 40 columns],
#  'Diff':                     Manufacturing  Durable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                  NaN                          NaN
#          2002             0.005086                          NaN
#          2003            -0.152991                          NaN
#          2004             0.258363                          NaN
#          2005             0.072797                          NaN
#  ...                           ...                          ...
#  56045   2016            -0.465655                          NaN
#          2017             0.268581                          NaN
#          2018                  NaN                          NaN
#          2019                  NaN                          NaN
#          2020                  NaN                          NaN
#
#                      Nondurable goods manufacturing  \
#  GeoFips TimePeriod
#  1001    2001                                   NaN
#          2002                                   NaN
#          2003                                   NaN
#          2004                                   NaN
#          2005                                   NaN
#  ...                                            ...
#  56045   2016                                   NaN
#          2017                                   NaN
#          2018                                   NaN
#          2019                              0.131033
#          2020                              0.095229
#
#                      Agriculture, forestry, fishing and hunting  \
#  GeoFips TimePeriod
#  1001    2001                                               NaN
#          2002                                         -0.217648
#          2003                                          0.793538
#          2004                                          0.222678
#          2005                                          0.169133
#  ...                                                        ...
#  56045   2016                                         -0.209103
#          2017                                          0.360970
#          2018                                          0.178369
#          2019                                         -0.516320
#          2020                                         -0.494913
#
#                      Mining, quarrying, and oil and gas extraction  Utilities  \
#  GeoFips TimePeriod
#  1001    2001                                                  NaN        NaN
#          2002                                            -0.419451   0.835570
#          2003                                             0.191126   0.068072
#          2004                                             0.470578   0.505041
#          2005                                             0.238805  -0.239593
#  ...                                                           ...        ...
#  56045   2016                                            -0.018912  -0.193847
#          2017                                            -0.009520  -0.026597
#          2018                                             0.206669   0.065212
#          2019                                             0.209558   0.195492
#          2020                                            -0.334780  -0.095830
#
#                      Construction  All industry total  Private industries  \
#  GeoFips TimePeriod
#  1001    2001                 NaN                 NaN                 NaN
#          2002           -0.468769            0.035414            0.025451
#          2003           -0.084355            0.024090            0.019010
#          2004            0.024750            0.149241            0.158717
#          2005           -0.180089            0.021172            0.024313
#  ...                          ...                 ...                 ...
#  56045   2016           -0.249158           -0.170054           -0.217398
#          2017           -0.338915           -0.014965           -0.015739
#          2018                 NaN            0.046818            0.051099
#          2019                 NaN            0.022713            0.033936
#          2020                 NaN           -0.031206           -0.038318
#
#                      Wholesale trade  ...  \
#  GeoFips TimePeriod                   ...
#  1001    2001                    NaN  ...
#          2002               0.104509  ...
#          2003               0.159748  ...
#          2004               0.001374  ...
#          2005               0.150375  ...
#  ...                             ...  ...
#  56045   2016                    NaN  ...
#          2017                    NaN  ...
#          2018                    NaN  ...
#          2019               0.000507  ...
#          2020               0.299654  ...
#
#                      Other services (except government and government enterprises)  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                 0.105066
#          2003                                                 0.047224
#          2004                                                -0.062444
#          2005                                                 0.036958
#  ...                                                               ...
#  56045   2016                                                -0.131513
#          2017                                                -0.033811
#          2018                                                 0.078863
#          2019                                                 0.022403
#          2020                                                 0.023416
#
#                      Government and government enterprises  \
#  GeoFips TimePeriod
#  1001    2001                                          NaN
#          2002                                     0.100051
#          2003                                     0.054375
#          2004                                     0.093238
#          2005                                     0.002148
#  ...                                                   ...
#  56045   2016                                     0.014899
#          2017                                    -0.012556
#          2018                                     0.030878
#          2019                                    -0.020473
#          2020                                    -0.007192
#
#                      Natural resources and mining     Trade  \
#  GeoFips TimePeriod
#  1001    2001                                 NaN       NaN
#          2002                           -0.235315  0.089228
#          2003                            0.755506  0.098954
#          2004                            0.235486  0.037887
#          2005                            0.174287  0.031026
#  ...                                          ...       ...
#  56045   2016                           -0.090373       NaN
#          2017                            0.130726       NaN
#          2018                            0.195076       NaN
#          2019                           -0.013248 -0.035913
#          2020                           -0.372324  0.051995
#
#                      All industry total 3YMA  Utilities 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                            NaN             NaN
#          2002                            NaN             NaN
#          2003                            NaN             NaN
#          2004                            NaN             NaN
#          2005                       0.072269        0.428654
#  ...                                     ...             ...
#  56045   2016                       0.035981        0.060306
#          2017                       0.034632       -0.015836
#          2018                       0.021498       -0.031208
#          2019                      -0.049461       -0.056311
#          2020                       0.018415        0.083922
#
#                      Mining, quarrying, and oil and gas extraction 3YMA  \
#  GeoFips TimePeriod
#  1001    2001                                                      NaN
#          2002                                                      NaN
#          2003                                                      NaN
#          2004                                                      NaN
#          2005                                                 0.105922
#  ...                                                               ...
#  56045   2016                                                 0.052770
#          2017                                                 0.053415
#          2018                                                 0.063915
#          2019                                                 0.063975
#          2020                                                 0.145328
#
#                      Agriculture, forestry, fishing and hunting 3YMA        M4  \
#  GeoFips TimePeriod
#  1001    2001                                                    NaN       NaN
#          2002                                                    NaN  0.055716
#          2003                                                    NaN  0.048757
#          2004                                                    NaN  0.054268
#          2005                                               0.293522  0.056201
#  ...                                                             ...       ...
#  56045   2016                                                    NaN  0.043443
#          2017                                                    NaN  0.043473
#          2018                                              -0.061192  0.052339
#          2019                                               0.123557  0.208567
#          2020                                               0.005596  0.097211
#
#                      M4 Interest Rate
#  GeoFips TimePeriod
#  1001    2001                     NaN
#          2002               -0.506924
#          2003                0.187600
#          2004                0.848066
#          2005                0.438499
#  ...                              ...
#  56045   2016                0.793637
#          2017                0.789168
#          2018                0.210036
#          2019               -1.422533
#          2020               -1.370897
#
#  [62360 rows x 40 columns]}

# %% [markdown]
# Remove years with nan

# %%
# remove duplicate first index column
def reset_index(df):
    name1,name2 = list(df.index.names)[1:]
    ix1, ix2 =df.index.get_level_values(1), df.index.get_level_values(2) 
    df[name1] = ix1
    df[name2] = ix2
    df.reset_index(drop=True, inplace = True)
    df.set_index(["GeoFips", "TimePeriod"], inplace = True)
    
ips_keys = ['Agriculture, forestry, fishing and hunting',
 'Mining, quarrying, and oil and gas extraction',
 'Utilities',
 "All industry total",
           "M4",
           "M4 Interest Rate"]
ips_df1 = data_dct1["Diff"][ips_keys]
ips_df1 = ips_df1[ips_df1.index.get_level_values("TimePeriod")>2001]
ips_df1 = ips_df1.groupby("GeoFips").apply(lambda x: x.dropna(axis = 1)).dropna()

ips_df1["M4 Interest Rate"] = data_df["M4 Interest Rate"]
ips_df1
# Out:
#                     Agriculture, forestry, fishing and hunting  \
# GeoFips TimePeriod
# 1001    2002                                         -0.217648
#         2003                                          0.793538
#         2004                                          0.222678
#         2005                                          0.169133
#         2006                                          0.176881
# ...                                                        ...
# 56041   2016                                          0.016426
#         2017                                         -0.156890
#         2018                                          0.231567
#         2019                                          0.839924
#         2020                                          0.274166
#
#                     Mining, quarrying, and oil and gas extraction  Utilities  \
# GeoFips TimePeriod
# 1001    2002                                            -0.419451   0.835570
#         2003                                             0.191126   0.068072
#         2004                                             0.470578   0.505041
#         2005                                             0.238805  -0.239593
#         2006                                             0.342614   0.436516
# ...                                                           ...        ...
# 56041   2016                                            -0.081156   0.211513
#         2017                                            -0.158175   0.004846
#         2018                                            -0.207405  -0.179435
#         2019                                            -0.452308   0.279935
#         2020                                            -0.747581  -0.020288
#
#                     All industry total        M4  M4 Interest Rate
# GeoFips TimePeriod
# 1001    2002                  0.035414  0.055716          0.007415
#         2003                  0.024090  0.048757          0.008946
#         2004                  0.149241  0.054268          0.020889
#         2005                  0.021172  0.056201          0.032386
#         2006                  0.066174  0.063476          0.033669
# ...                                ...       ...               ...
# 56041   2016                 -0.006544  0.043443          0.003105
#         2017                 -0.023853  0.043473          0.006835
#         2018                 -0.037587  0.052339          0.008433
#         2019                 -0.024081  0.208567          0.002033
#         2020                 -0.108416  0.097211          0.000516
#
# [11343 rows x 6 columns]

# %%
# years = ips_df.groupby("TimePeriod").mean().index
# entities = ips_df.groupby("GeoFips").mean().index
# years, entities

# %% [markdown]
# enter data that is the same for *every* year entry
#
# using year as example for data entry here

# %%
# df = ips_df.copy()
# df["New"] = np.nan
# for year in years:
#     df["New"][df.index.get_level_values("TimePeriod") == year] = year
# df

# %%
ips_dct = {"Log":ips_df}
ips_dct["Rates"] = ips_dct["Log"].groupby("GeoFips").diff()
ips_dct["Diff"] = ips_dct["Rates"].groupby("GeoFips").diff()

# %% [markdown]
# Run the IPS test

# %%
# import statsmodels.api as sm 
from statsmodels.tsa.stattools import adfuller

def ips_test(data):
    index_name, sub_index_name = data.index.names
    index = list(data.reset_index()[index_name].unique())
    N = len(index)
    t_stats = {}
    df_index_dict = {}
    for ix in index:
        slice_df = data.loc[ix]
#         print(slice_df)
        t_stats[ix] = {}
        for key in slice_df.keys():
            try:
                t_stat = adfuller(slice_df[key], maxlag = 1, regression = 'c')[0]
                t_stats[ix][key] = t_stat
            except:
                print("Error:", key)
    t_stats = pd.DataFrame(t_stats).T

    return t_stats.mean()
   
ips_results = {}
for key, val in ips_dct.items():
    ips_results[key] = ips_test(val.dropna())
pd.DataFrame(ips_results).dropna()
# Out:
#                                                     Log     Rates      Diff
# Agriculture, forestry, fishing and hunting    -5.414102 -6.708298 -7.180468
# Mining, quarrying, and oil and gas extraction -4.065713 -5.900292 -6.764893
# Utilities                                     -4.718953 -6.403677 -7.053029
# All industry total                            -3.889409 -5.733595 -6.582149

# %%
ips_dct2 = {"Log":ips_df1}
ips_dct2["Rates"] = ips_dct2["Log"].groupby("GeoFips").diff()
ips_dct2["Diff"] = ips_dct2["Rates"].groupby("GeoFips").diff()

# %%
# import statsmodels.api as sm 
from statsmodels.tsa.stattools import adfuller

def ips_test(data):
    index_name, sub_index_name = data.index.names
    index = list(data.reset_index()[index_name].unique())
    N = len(index)
    t_stats = {}
    df_index_dict = {}
    for ix in index:
        slice_df = data.loc[ix]
#         print(slice_df)
        t_stats[ix] = {}
        for key in slice_df.keys():
            try:
                t_stat = adfuller(slice_df[key], maxlag = 1, regression = 'c')[0]
                t_stats[ix][key] = t_stat
            except:
                print("Error:", key)
    t_stats = pd.DataFrame(t_stats).T

    return t_stats.mean()
   
ips_results = {}
for key, val in ips_dct2.items():
    ips_results[key] = ips_test(val.dropna())
pd.DataFrame(ips_results).dropna()
# Out:
#                                                     Log     Rates      Diff
# Agriculture, forestry, fishing and hunting    -5.414102 -6.708298 -7.180468
# Mining, quarrying, and oil and gas extraction -4.065713 -5.900292 -6.764893
# Utilities                                     -4.718953 -6.403677 -7.053029
# All industry total                            -3.889409 -5.733595 -6.582149
# M4                                            -2.543850 -5.198218 -4.359977
# M4 Interest Rate                              -2.680603 -4.714092 -4.381624

# %%
import pingouin
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams.update({'font.size': 30})
plt.rcParams['axes.xmargin'] = .001
plt.rcParams['axes.ymargin'] = .005
def full_corr_plot(data, color = "C0", pcorr = False):
    if pcorr == True:
        corr_df = data.pcorr()
    elif pcorr == False:
        corr_df = data.corr()
    keys = list(corr_df.keys())
    dim = len(keys)

    fig, ax = plt.subplots(figsize = (30, 30))
    a = pd.plotting.scatter_matrix(data, c = color, 
                                   s = 200, alpha = .1, ax=ax)  
    for i in range(len(keys)):
        x = keys[i]
        for j in range(len(keys)):
            y = keys[j]
            a[i][j].set_xticklabels([])
            a[i][j].set_yticklabels([])
            a[i][j].set_title("$\\rho :" + str(corr_df.round(2)[x][y])+ "$", y = .88, x = 0.01, ha = "left")        
    plt.suptitle("Correlation\n(Color: y)",y = .96, fontsize = 80)
plot_df = ips_dct2['Diff'].dropna()
plot_df.rename(columns = {key:key.replace(" ", "\n") for key in plot_df.keys()}, inplace = True)
plot_keys = list(plot_df.keys())
full_corr_plot(plot_df, color = plot_df[plot_keys[0]], pcorr = True)
# y_var = ['Agriculture, forestry, fishing and hunting']
# x_vars = ['Mining, quarrying, and oil and gas extraction', 'Utilities', 'Construction', 'Manufacturing']
# corr_var = y_var + x_vars
# corr_data = log_df[corr_var]
# corr_data.corr().round(3)
# Out:
# C:\Users\abiodun.idowu\Anaconda3\envs\python37\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\abiodun.idowu\Anaconda3\envs\python37\lib\site-packages\ipykernel_launcher.py:17: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
# C:\Users\abiodun.idowu\Anaconda3\envs\python37\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# C:\Users\abiodun.idowu\Anaconda3\envs\python37\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
import numpy as np
# . . .
def corr_matrix_heatmap(data, pp = False):  
    #Create a figure to visualize a corr matrix  
    fig, ax = plt.subplots(figsize=(20,20))  
    # use ax.imshow() to create a heatmap of correlation values  
    # seismic mapping shows negative values as blue and positive values as red  
    im = ax.imshow(data, norm = plt.cm.colors.Normalize(-1,1), cmap = "seismic")  
    # create a list of labels, stacking each word in a label by replacing " "  
    # with "\n"  
    labels = data.keys()  
    num_vars = len(labels)  
    tick_labels = [lab.replace(" ", "\n") for lab in labels]  
    # adjust font size according to the number of variables visualized  
    tick_font_size = 120 / num_vars  
    val_font_size = 200 / num_vars  
    plt.rcParams.update({'font.size': tick_font_size}) 
    # prepare space for label of each column  
    x_ticks = np.arange(num_vars)  
    # select labels and rotate them 90 degrees so that they are vertical  
    plt.xticks(x_ticks, tick_labels, fontsize = tick_font_size, rotation = 90)  
    # prepare space for label of each row  
    y_ticks = np.arange(len(labels))  
    # select labels  
    plt.yticks(y_ticks, tick_labels, fontsize = tick_font_size)  
    # show values in each tile of the heatmap  
    for i in range(len(labels)):  
        for j in range(len(labels)):  
            text = ax.text(i, j, str(round(data.values[i][j],2)),  
                           fontsize= val_font_size, ha="center",   
                           va="center", color = "w")  
    #Create title with Times New Roman Font  
    title_font = {"fontname":"Times New Roman"}  
    plt.title("Correlation", fontsize = 50, **title_font)  
    #Call scale to show value of colors 
    cbar = fig.colorbar(im)
    plt.show()
    if pp != False:
        pp.savefig(fig, bbox_inches="tight")
    plt.close()

#. . . 
# . . .
corr_matrix_heatmap(plot_df.corr())

# %%
# list(plot_df)
# ips_df
plot_df.rename(columns = {key:key[:4].replace("\n", "") for key in plot_df.keys()}, inplace = True)
list(plot_df.keys())
# Out:
# ['Agri', 'Mini', 'Util', 'All', 'M4', 'M4I']

# %%
undirected_graph = {key:[] for key in plot_df.keys()}
for x in undirected_graph:
    remaining_vars = [y for y in plot_df.keys() if y != x]
    for y in remaining_vars:
        undirected_graph[x].append(y)

# %%
import copy
p_value = .05

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
from pgmpy.estimators import PC
c = PC(plot_df)
max_cond_vars = len(plot_df.keys()) - 2

model = c.estimate(return_type = 'pdag', variant= 'parallel', significance_level = p_value,
                  max_cond_vars = max_cond_vars, ci_test = 'pearsonr')
edges = model.edges
# Out:
# Working for n conditional variables: 4: 100%|████████████████████████████████████████████| 4/4 [00:00<00:00,  4.58it/s]

# %%
from matplotlib.patches import ArrowStyle

def graph_DAG(edges, plot_df, title = ""):
    graph = nx.DiGraph()
    graph.add_edges_from(edges)
    color_map = ['C7' for g in graph]
    
    fig, ax = plt.subplots(figsize = (20, 12))
    graph.nodes()
    plt.tight_layout()
    pos = nx.spring_layout(graph)
    
    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, pos, node_color=color_map, node_size = 1200,
                    with_labels=True, arrows=True, font_color = 'k',
                    font_size = 26, alpha =1, width = 1, edge_color = 'C1',
                    arrowstyle=ArrowStyle('Fancy, head_length=3, head_width=1.5, tail_width=.1'), ax = ax)
graph_DAG(edges, plot_df, title = 'Directed Acyclic Graph')
edges
# Out:
# OutEdgeView([('Agri', 'All'), ('Agri', 'M4'), ('Util', 'All'), ('Util', 'M4')])

# %%
def grap_DAG(edges, plot_df, title = ""):
    graph = nx.Graph()
    edge_labels = {}
    for edge in edges:
        controls = [key for key in plot_df.keys() if key not in edge]
        controls = list(set(controls))
        keep_controls = []
        for control in controls:
            control_edges = [ctrl_edge for ctrl_edge in edges if control == ctrl_edge[0]]
            if (control, edge[1]) in control_edges:
                print('keep control:', control)
                keep_controls.append(control)
        print(edge, keep_controls)
        pcorr = plot_df[[edge[0], edge[1]]+keep_controls].pcorr()
        edge_labels[edge] = str(round(pcorr[edge[0]].loc[edge[1]],2))
    graph.add_edges_from(edges)
    color_map = ['C0' for g in graph]
    
    fig, ax = plt.subplots(figsize = (20, 12))
    graph.nodes()
    plt.tight_layout()
    pos = nx.spring_layout(graph)
    
    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, pos, node_color=color_map, node_size=1200, with_labels=True,
                    arrows=True, font_color ='k', font_size=26, alpha=1, width = 1,
                    edge_color = 'C1',
                     arrowstyle=ArrowStyle('Fancy, head_length=3, head_width=1.5, tail_width=.1'), ax = ax)
    nx.draw_netwrokx_edge_labels(graph, pos, edge_labels=edge_labels, font_color='green', font_size=20)
    
graph_DAG(edges, plot_df, title = 'Directed Acyclic Graph')

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %% [markdown]
# ### DAGs with multiple significance levels

# %%
def grap_DAG(edges, plot_df, title = ""):
    graph = nx.Graph()
    edge_labels = {}
    for edge in edges:
        controls = [key for key in plot_df.keys() if key not in edge]
        controls = list(set(controls))
        keep_controls = []
        for control in controls:
            control_edges = [ctrl_edge for ctrl_edge in edges if control == ctrl_edge[0]]
            if (control, edge[1]) in control_edges:
                print('keep control:', control)
                keep_controls.append(control)
        print(edge, keep_controls)
        pcorr = plot_df[[edge[0], edge[1]]+keep_controls].pcorr()
        edge_labels[edge] = str(round(pcorr[edge[0]].loc[edge[1]],2))
    graph.add_edges_from(edges)
    color_map = ['C0' for g in graph]
    
    fig, ax = plt.subplots(figsize = (20, 12))
    graph.nodes()
    plt.tight_layout()
    pos = nx.spring_layout(graph)
    
    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, pos, node_color=color_map, node_size=1200, with_labels=True,
                    arrows=True, font_color ='k', font_size=26, alpha=1, width = 1,
                    edge_color = 'C1',
                     arrowstyle=ArrowStyle('Fancy, head_length=3, head_width=1.5, tail_width=.1'), ax = ax)
    nx.draw_netwrokx_edge_labels(graph, pos, edge_labels=edge_labels, font_color='green', font_size=20)


pp = PdfPages("DAGOutputs.pdf")
DAG_models_vars = {7:["Agri", "Mini", "Uti", "All", "M4", "M4I"]}

# link_sigs = [0.05, 0.1, 0.2]
link_sigs = [0.01, .05, .1]
algorithms = ["orig", "stable", "parallel"]
for keys in DAG_models_vars.values():
    fig, ax = plt.subplots(len(algorithms), len(link_sigs), figsize = (30,30))
    max_cond_vars = len(keys) - 2
    #data_reg = data[keys].dropna()
    #data_reg.rename(columns = {col:firstLetterWord(col) for col in keys}, inplace = True)
#     keys = plot_df.keys()
#     c = PC(plot_df[keys].dropna())
    max_cond_vars = len(keys) - 2
    i,j = 0,0
    for sig in link_sigs:
        for algorithm in algorithms:
            model = c.estimate(return_type = "pdag", variant = algorithm, 
                               significance_level = sig, 
                               max_cond_vars = max_cond_vars, ci_test = "chi_square")
            edges = model.edges()
            pcorr = plot_df.pcorr()
            weights = {}
            a = ax[i][j]
#             graph_DAG(edges, plot_df, fig = fig, ax = a)
        
            if j == 0:
                a.set_ylabel(algorithm, fontsize = 20)
            if i == len(algorithms) - 1:
                a.set_xlabel("$p \leq$ "+ str(sig), fontsize = 20)
            i += 1
        j += 1
        i = 0
    plt.suptitle(str(list(keys)).replace("[","").replace("]",""), fontsize = 40, y =1.035)
    plt.show()
    pp.savefig(fig, bbox_inches = "tight")
    plt.close()
pp.close()
edges
# Out:
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:20<00:20, 10.27s/it]
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:19<00:19,  9.95s/it]
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:28<00:28, 14.22s/it]
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:19<00:19,  9.57s/it]
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:19<00:19,  9.86s/it]
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:16<00:16,  8.42s/it]
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:18<00:18,  9.45s/it]
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:18<00:18,  9.40s/it]
# Working for n conditional variables: 2:  50%|██████████████████████                      | 2/4 [00:20<00:20, 10.04s/it]
# OutEdgeView([('M4', 'M4I'), ('M4I', 'M4')])
