# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from pgmpy.estimators import PC
from abbeyFunctions import graph_DAG
from abiFunctions import analyze_wls_pooled_models, wls_pooled_model_analysis
import pingouin

# %% [markdown]
# Import dataframes for plotting the full DAGs

# %%
diff_nominal = pd.read_csv('diff_nominal.csv')

diff_nominal.drop(columns=['Unnamed: 0'], inplace=True)

rates_nominal = pd.read_csv('rates_nominal.csv')

rates_nominal.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Creating a dictionary to store the various combinations fo the dataframes for the DAGs

# %%
nominal_differenced_rates_with_all_variables = diff_nominal.dropna().set_index(['FIPS', 'TimePeriod'])

nominal_rates_with_all_variables = rates_nominal.dropna().set_index(['FIPS', 'TimePeriod'])

# Create a dictionary to store the DataFrames
full_DAG_dict = {}

full_DAG_dict['Nominal rates (All variables)'] = nominal_rates_with_all_variables

full_DAG_dict['Nominal rates (without Monetary)'] = nominal_rates_with_all_variables.drop(columns=['M4', 'M4I'])

full_DAG_dict['Nominal rates (without unem)'] = nominal_rates_with_all_variables.drop(columns=['unem'])

full_DAG_dict['Nominal diff rates (All variables)'] = nominal_differenced_rates_with_all_variables

full_DAG_dict['Nominal diff rates (without Monetary)'] = nominal_differenced_rates_with_all_variables.drop(columns=['M4', 'M4I'])

full_DAG_dict['Nominal diff rates (without unem)'] = nominal_differenced_rates_with_all_variables.drop(columns=['unem'])

# %% [markdown]
# Here we plot the DAGs

# %%
title = ['Nominal rates DAGs including all variables',
        'Nominal rates DAGs without monetary variables',
        'Nominal rates DAGs without unemployment ',
        'Nominal diff rates DAGs including all variables',
        'Nominal diff rates DAGs without monetary variables',
        'Nominal diff rates DAGs without unemployment ']

# Plot DAGs for each dataframe
for i, key in enumerate(['Nominal rates (All variables)',
                         'Nominal rates (without Monetary)',
                         'Nominal rates (without unem)',
                         'Nominal diff rates (All variables)',
                         'Nominal diff rates (without Monetary)',
                         'Nominal diff rates (without unem)']):
    plot_df = full_DAG_dict[key]
    c = PC(plot_df)
    max_cond_vars = len(plot_df.keys()) - 2
    model = c.estimate(return_type='pdag', variant='orig', significance_level=0.01,
                       max_cond_vars=max_cond_vars, ci_test='pearsonr')
    edges = model.edges

    # Plot the DAG
    graph_DAG(edges, plot_df, title=title[i])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ('M4I', 'Mini') []
# keep control: Util
# ('M4I', 'M4') ['Util']
# keep control: M4
# keep control: Util
# ('Mini', 'unem') ['M4', 'Util']
# ('unem', 'M4I') []
# keep control: Mini
# keep control: Util
# ('M4', 'unem') ['Mini', 'Util']
# keep control: Mini
# keep control: M4
# ('Util', 'unem') ['Mini', 'M4']
# keep control: M4I
# ('Util', 'M4') ['M4I']
#   0%|          | 0/2 [00:00<?, ?it/s]
# keep control: Mini
# ('Util', 'unem') ['Mini']
# keep control: Util
# ('Mini', 'unem') ['Util']
#   0%|          | 0/3 [00:00<?, ?it/s]
# ('M4I', 'M4') []
# ('M4', 'Util') []
# keep control: Util
# ('Mini', 'M4I') ['Util']
# keep control: Mini
# ('Util', 'M4I') ['Mini']
#   0%|          | 0/4 [00:00<?, ?it/s]
# keep control: Util
# ('Agri', 'M4') ['Util']
# ('M4', 'unem') []
# ('unem', 'Mini') []
# keep control: Mini
# ('unem', 'M4I') ['Mini']
# keep control: unem
# ('Mini', 'M4I') ['unem']
# keep control: Agri
# ('Util', 'M4') ['Agri']
#   0%|          | 0/2 [00:00<?, ?it/s]
# keep control: Mini
# keep control: Agri
# ('Util', 'unem') ['Mini', 'Agri']
# keep control: Mini
# keep control: Util
# ('Agri', 'unem') ['Mini', 'Util']
# keep control: Agri
# keep control: Util
# ('Mini', 'unem') ['Agri', 'Util']
#   0%|          | 0/3 [00:00<?, ?it/s]
# keep control: Mini
# keep control: Agri
# keep control: Util
# ('M4I', 'M4') ['Mini', 'Agri', 'Util']
# ('M4I', 'Mini') []
# keep control: M4I
# keep control: Mini
# keep control: Util
# ('Agri', 'M4') ['M4I', 'Mini', 'Util']
# keep control: M4I
# keep control: Agri
# keep control: Util
# ('Mini', 'M4') ['M4I', 'Agri', 'Util']
# ('Mini', 'M4I') []
# keep control: M4I
# keep control: Mini
# keep control: Agri
# ('Util', 'M4') ['M4I', 'Mini', 'Agri']

# %% [markdown]
# Import dataframes for and fit the models (WLS and PooledOLS)

# %%
full_df_rates_cluster = pd.read_csv('full_df_rates_cluster.csv')

full_df_diff_cluster = pd.read_csv('full_df_diff_cluster.csv')

# %% [markdown]
# Here we use a function to fit the models and compare their results side by side.

# %%
data_cluster_dict = {
    'Nominal rates with clusters': pd.get_dummies(full_df_rates_cluster, columns=['clusters'], drop_first=True),
    'Nominal diff rates with clusters': pd.get_dummies(full_df_diff_cluster, columns=['clusters'], drop_first=True)
}

result_df = analyze_wls_pooled_models(data_cluster_dict, 
                                      dependent_var='unem', 
                                      k=5, shuffle=True, random_state=42, check_rank=False)

# Display the result DataFrame
# print("\nResult DataFrame:")
display(result_df)
# Out:
#               Nominal rates with clusters - True - WLS  \
# const                                         6.409185
# Agri                                         -0.137074
# Mini                                          0.053058
# Util                                         -0.252740
# M4                                          -10.523388
# M4I                                         -14.745899
# clusters_2.0                                 -1.168032
# clusters_3.0                                 -2.199948
# clusters_4.0                                  3.217713
# $R^2$                                         0.529896
# Avg MSE                                       4.246339
# MSE Fold 1                                    4.504153
# MSE Fold 2                                    4.099214
# MSE Fold 3                                    4.446921
# MSE Fold 4                                    3.956104
# MSE Fold 5                                    4.225302
#
#               Nominal rates with clusters - True - PooledOLS  \
# const                                               8.347885
# Agri                                                0.017712
# Mini                                               -0.185994
# Util                                               -0.019477
# M4                                                -18.561302
# M4I                                               -52.294486
# clusters_2.0                                       -1.744850
# clusters_3.0                                       -3.305374
# clusters_4.0                                        2.716022
# $R^2$                                               0.567320
# Avg MSE                                             3.146079
# MSE Fold 1                                          4.504153
# MSE Fold 2                                          4.099214
# MSE Fold 3                                          4.446921
# MSE Fold 4                                          3.956104
# MSE Fold 5                                          4.225302
#
#               Nominal rates with clusters - False - WLS  \
# const                                          5.161540
# Agri                                          -0.215377
# Mini                                          -0.251221
# Util                                          -0.158226
# M4                                           -11.122121
# M4I                                           -5.817140
# clusters_2.0                                        NaN
# clusters_3.0                                        NaN
# clusters_4.0                                        NaN
# $R^2$                                          0.080092
# Avg MSE                                        8.696660
# MSE Fold 1                                     9.002886
# MSE Fold 2                                     8.768923
# MSE Fold 3                                     8.692761
# MSE Fold 4                                     8.524399
# MSE Fold 5                                     8.494331
#
#               Nominal rates with clusters - False - PooledOLS  \
# const                                                7.481428
# Agri                                                -0.014992
# Mini                                                -0.262775
# Util                                                -0.134283
# M4                                                 -18.991674
# M4I                                                -51.137231
# clusters_2.0                                              NaN
# clusters_3.0                                              NaN
# clusters_4.0                                              NaN
# $R^2$                                                0.171885
# Avg MSE                                              5.984247
# MSE Fold 1                                           9.002886
# MSE Fold 2                                           8.768923
# MSE Fold 3                                           8.692761
# MSE Fold 4                                           8.524399
# MSE Fold 5                                           8.494331
#
#               Nominal diff rates with clusters - True - WLS  \
# const                                                   NaN
# Agri                                               0.033675
# Mini                                              -0.010289
# Util                                              -0.083209
# M4                                                -4.454320
# M4I                                               -4.157394
# clusters_2.0                                      -1.007501
# clusters_3.0                                      -0.046477
# clusters_4.0                                      -0.346045
# $R^2$                                              1.000000
# Avg MSE                                            2.240740
# MSE Fold 1                                         2.345374
# MSE Fold 2                                         2.366068
# MSE Fold 3                                         1.569994
# MSE Fold 4                                         2.390989
# MSE Fold 5                                         2.531274
#
#               Nominal diff rates with clusters - True - PooledOLS  \
# const                                                       NaN
# Agri                                                   0.007445
# Mini                                                  -0.045978
# Util                                                  -0.014574
# M4                                                   -12.920005
# M4I                                                  -40.960234
# clusters_2.0                                           0.081459
# clusters_3.0                                           0.054413
# clusters_4.0                                           0.027170
# $R^2$                                                  0.265907
# Avg MSE                                                1.521757
# MSE Fold 1                                             2.345374
# MSE Fold 2                                             2.366068
# MSE Fold 3                                             1.569994
# MSE Fold 4                                             2.390989
# MSE Fold 5                                             2.531274
#
#               Nominal diff rates with clusters - False - WLS  \
# const                                                    NaN
# Agri                                               -2.005811
# Mini                                               -1.333057
# Util                                                1.247362
# M4                                                231.327895
# M4I                                                 5.161458
# clusters_2.0                                             NaN
# clusters_3.0                                             NaN
# clusters_4.0                                             NaN
# $R^2$                                               1.000000
# Avg MSE                                           217.479714
# MSE Fold 1                                        263.494606
# MSE Fold 2                                        277.079653
# MSE Fold 3                                          1.527999
# MSE Fold 4                                        275.680039
# MSE Fold 5                                        269.616274
#
#               Nominal diff rates with clusters - False - PooledOLS
# const                                                       NaN
# Agri                                                   0.007534
# Mini                                                  -0.047358
# Util                                                  -0.015957
# M4                                                   -12.874148
# M4I                                                  -41.252649
# clusters_2.0                                                NaN
# clusters_3.0                                                NaN
# clusters_4.0                                                NaN
# $R^2$                                                  0.264344
# Avg MSE                                                1.524481
# MSE Fold 1                                           263.494606
# MSE Fold 2                                           277.079653
# MSE Fold 3                                             1.527999
# MSE Fold 4                                           275.680039
# MSE Fold 5                                           269.616274

# %%
# Compare wls and pooledOLS regressions using k-fold and iterations
data_cluster_dict = {
    'Nominal rates with clusters': pd.get_dummies(full_df_rates_cluster, columns=['clusters'], drop_first=True),
    'Nominal diff rates with clusters': pd.get_dummies(full_df_diff_cluster, columns=['clusters'], drop_first=True)
}

result_df = analyze_wls_pooled_models(data_cluster_dict, dependent_var='unem', k=5, shuffle=True, random_state=42, check_rank=True, num_iterations=10)
display(result_df)
# Out:
#               Nominal rates with clusters - True - WLS  \
# const                                         6.409185
# Agri                                         -0.137074
# Mini                                          0.053058
# Util                                         -0.252740
# M4                                          -10.523388
# M4I                                         -14.745899
# clusters_2.0                                 -1.168032
# clusters_3.0                                 -2.199948
# clusters_4.0                                  3.217713
# $R^2$                                         0.529896
# Avg MSE                                       4.246339
# MSE Fold 1                                    4.504153
# MSE Fold 2                                    4.099214
# MSE Fold 3                                    4.446921
# MSE Fold 4                                    3.956104
# MSE Fold 5                                    4.225302
#
#               Nominal rates with clusters - True - PooledOLS  \
# const                                               8.347885
# Agri                                                0.017712
# Mini                                               -0.185994
# Util                                               -0.019477
# M4                                                -18.561302
# M4I                                               -52.294486
# clusters_2.0                                       -1.744850
# clusters_3.0                                       -3.305374
# clusters_4.0                                        2.716022
# $R^2$                                               0.567320
# Avg MSE                                             3.146079
# MSE Fold 1                                          4.504153
# MSE Fold 2                                          4.099214
# MSE Fold 3                                          4.446921
# MSE Fold 4                                          3.956104
# MSE Fold 5                                          4.225302
#
#               Nominal rates with clusters - False - WLS  \
# const                                          5.161540
# Agri                                          -0.215377
# Mini                                          -0.251221
# Util                                          -0.158226
# M4                                           -11.122121
# M4I                                           -5.817140
# clusters_2.0                                        NaN
# clusters_3.0                                        NaN
# clusters_4.0                                        NaN
# $R^2$                                          0.080092
# Avg MSE                                        8.696660
# MSE Fold 1                                     9.002886
# MSE Fold 2                                     8.768923
# MSE Fold 3                                     8.692761
# MSE Fold 4                                     8.524399
# MSE Fold 5                                     8.494331
#
#               Nominal rates with clusters - False - PooledOLS  \
# const                                                7.481428
# Agri                                                -0.014992
# Mini                                                -0.262775
# Util                                                -0.134283
# M4                                                 -18.991674
# M4I                                                -51.137231
# clusters_2.0                                              NaN
# clusters_3.0                                              NaN
# clusters_4.0                                              NaN
# $R^2$                                                0.171885
# Avg MSE                                              5.984247
# MSE Fold 1                                           9.002886
# MSE Fold 2                                           8.768923
# MSE Fold 3                                           8.692761
# MSE Fold 4                                           8.524399
# MSE Fold 5                                           8.494331
#
#               Nominal diff rates with clusters - True - WLS  \
# const                                                   NaN
# Agri                                               0.033675
# Mini                                              -0.010289
# Util                                              -0.083209
# M4                                                -4.454320
# M4I                                               -4.157394
# clusters_2.0                                      -1.007501
# clusters_3.0                                      -0.046477
# clusters_4.0                                      -0.346045
# $R^2$                                              1.000000
# Avg MSE                                            2.240740
# MSE Fold 1                                         2.345374
# MSE Fold 2                                         2.366068
# MSE Fold 3                                         1.569994
# MSE Fold 4                                         2.390989
# MSE Fold 5                                         2.531274
#
#               Nominal diff rates with clusters - True - PooledOLS  \
# const                                                       NaN
# Agri                                                   0.007445
# Mini                                                  -0.045978
# Util                                                  -0.014574
# M4                                                   -12.920005
# M4I                                                  -40.960234
# clusters_2.0                                           0.081459
# clusters_3.0                                           0.054413
# clusters_4.0                                           0.027170
# $R^2$                                                  0.265907
# Avg MSE                                                1.521757
# MSE Fold 1                                             2.345374
# MSE Fold 2                                             2.366068
# MSE Fold 3                                             1.569994
# MSE Fold 4                                             2.390989
# MSE Fold 5                                             2.531274
#
#               Nominal diff rates with clusters - False - WLS  \
# const                                                    NaN
# Agri                                               -2.005811
# Mini                                               -1.333057
# Util                                                1.247362
# M4                                                231.327895
# M4I                                                 5.161458
# clusters_2.0                                             NaN
# clusters_3.0                                             NaN
# clusters_4.0                                             NaN
# $R^2$                                               1.000000
# Avg MSE                                           217.479714
# MSE Fold 1                                        263.494606
# MSE Fold 2                                        277.079653
# MSE Fold 3                                          1.527999
# MSE Fold 4                                        275.680039
# MSE Fold 5                                        269.616274
#
#               Nominal diff rates with clusters - False - PooledOLS
# const                                                       NaN
# Agri                                                   0.007534
# Mini                                                  -0.047358
# Util                                                  -0.015957
# M4                                                   -12.874148
# M4I                                                  -41.252649
# clusters_2.0                                                NaN
# clusters_3.0                                                NaN
# clusters_4.0                                                NaN
# $R^2$                                                  0.264344
# Avg MSE                                                1.524481
# MSE Fold 1                                           263.494606
# MSE Fold 2                                           277.079653
# MSE Fold 3                                             1.527999
# MSE Fold 4                                           275.680039
# MSE Fold 5                                           269.616274

# %%
# Compare regressions without using k-fold
data_cluster_dict = {
    'Nominal rates with clusters': pd.get_dummies(full_df_rates_cluster, columns=['clusters'], drop_first=True),
    'Nominal diff rates with clusters': pd.get_dummies(full_df_diff_cluster, columns=['clusters'], drop_first=True)
}

result_df = wls_pooled_model_analysis(data_cluster_dict, dependent_var='unem', random_state=42, check_rank=True)
display(result_df)
# Out:
#               Nominal rates with clusters - True - WLS  \
# const                                         6.334052
# Agri                                         -0.125716
# Mini                                          0.038322
# Util                                         -0.255836
# M4                                          -10.597036
# M4I                                         -11.038222
# clusters_2.0                                 -1.182594
# clusters_3.0                                 -2.150533
# clusters_4.0                                  3.250076
# $R^2$                                         0.506467
#
#               Nominal rates with clusters - True - PooledOLS  \
# const                                               8.337984
# Agri                                                0.016599
# Mini                                               -0.187466
# Util                                               -0.010568
# M4                                                -18.483170
# M4I                                               -52.275744
# clusters_2.0                                       -1.737980
# clusters_3.0                                       -3.299922
# clusters_4.0                                        2.747771
# $R^2$                                               0.565235
#
#               Nominal rates with clusters - False - WLS  \
# const                                          5.139605
# Agri                                          -0.217620
# Mini                                          -0.254928
# Util                                          -0.169160
# M4                                           -11.156452
# M4I                                           -4.347760
# clusters_2.0                                        NaN
# clusters_3.0                                        NaN
# clusters_4.0                                        NaN
# $R^2$                                          0.073903
#
#               Nominal rates with clusters - False - PooledOLS  \
# const                                                7.480846
# Agri                                                -0.018518
# Mini                                                -0.252104
# Util                                                -0.113370
# M4                                                 -18.818965
# M4I                                                -51.405821
# clusters_2.0                                              NaN
# clusters_3.0                                              NaN
# clusters_4.0                                              NaN
# $R^2$                                                0.168962
#
#               Nominal diff rates with clusters - True - WLS  \
# const                                                   NaN
# Agri                                               0.032392
# Mini                                              -0.025103
# Util                                              -0.092690
# M4                                                -3.963226
# M4I                                                0.034615
# clusters_2.0                                      -1.200555
# clusters_3.0                                      -0.051279
# clusters_4.0                                      -0.358105
# $R^2$                                              1.000000
#
#               Nominal diff rates with clusters - True - PooledOLS  \
# const                                                       NaN
# Agri                                                   0.013761
# Mini                                                  -0.044479
# Util                                                  -0.018723
# M4                                                   -13.200470
# M4I                                                  -40.775526
# clusters_2.0                                           0.079666
# clusters_3.0                                           0.052465
# clusters_4.0                                           0.041203
# $R^2$                                                  0.271565
#
#               Nominal diff rates with clusters - False - WLS  \
# const                                                    NaN
# Agri                                               -2.514829
# Mini                                               -1.525938
# Util                                                1.471466
# M4                                                291.243139
# M4I                                                11.384242
# clusters_2.0                                             NaN
# clusters_3.0                                             NaN
# clusters_4.0                                             NaN
# $R^2$                                               1.000000
#
#               Nominal diff rates with clusters - False - PooledOLS
# const                                                       NaN
# Agri                                                   0.013913
# Mini                                                  -0.045985
# Util                                                  -0.020116
# M4                                                   -13.158374
# M4I                                                  -41.111858
# clusters_2.0                                                NaN
# clusters_3.0                                                NaN
# clusters_4.0                                                NaN
# $R^2$                                                  0.270058

# %% [markdown]
# Here we fit the regressions and report all the mse's from all the iterations

# %%
from abiFunctions import analyze_wls_pooled_models_all_mse

result_all = analyze_wls_pooled_models_all_mse(data_cluster_dict, dependent_var='unem', k=5, shuffle=True, random_state=42, check_rank=True, num_iterations=10)
display(result_all)
# Out:
#              Nominal rates with clusters - True - WLS  \
# const                                        6.409185
# Agri                                        -0.137074
# Mini                                         0.053058
# Util                                        -0.252740
# M4                                         -10.523388
# ...                                               ...
# MSE Fold 46                                  4.504153
# MSE Fold 47                                  4.099214
# MSE Fold 48                                  4.446921
# MSE Fold 49                                  3.956104
# MSE Fold 50                                  4.225302
#
#              Nominal rates with clusters - True - PooledOLS  \
# const                                              8.337992
# Agri                                               0.016636
# Mini                                              -0.187647
# Util                                              -0.010630
# M4                                               -18.482976
# ...                                                     ...
# MSE Fold 46                                        3.098234
# MSE Fold 47                                        2.940928
# MSE Fold 48                                        3.011729
# MSE Fold 49                                        2.958419
# MSE Fold 50                                        3.146079
#
#              Nominal rates with clusters - False - WLS  \
# const                                         5.161540
# Agri                                         -0.215377
# Mini                                         -0.251221
# Util                                         -0.158226
# M4                                          -11.122121
# ...                                                ...
# MSE Fold 46                                   9.002886
# MSE Fold 47                                   8.768923
# MSE Fold 48                                   8.692761
# MSE Fold 49                                   8.524399
# MSE Fold 50                                   8.494331
#
#              Nominal rates with clusters - False - PooledOLS  \
# const                                               7.480873
# Agri                                               -0.018511
# Mini                                               -0.252205
# Util                                               -0.113294
# M4                                                -18.818804
# ...                                                      ...
# MSE Fold 46                                         5.860445
# MSE Fold 47                                         5.685814
# MSE Fold 48                                         5.728239
# MSE Fold 49                                         5.709064
# MSE Fold 50                                         5.984247
#
#              Nominal diff rates with clusters - True - WLS  \
# const                                                  NaN
# Agri                                              0.033675
# Mini                                             -0.010289
# Util                                             -0.083209
# M4                                               -4.454320
# ...                                                    ...
# MSE Fold 46                                       2.345374
# MSE Fold 47                                       2.366068
# MSE Fold 48                                       1.569994
# MSE Fold 49                                       2.390989
# MSE Fold 50                                       2.531274
#
#              Nominal diff rates with clusters - True - PooledOLS  \
# const                                                      NaN
# Agri                                                  0.013734
# Mini                                                 -0.044505
# Util                                                 -0.018781
# M4                                                  -13.200490
# ...                                                        ...
# MSE Fold 46                                           1.479607
# MSE Fold 47                                           1.445109
# MSE Fold 48                                           1.421589
# MSE Fold 49                                           1.437620
# MSE Fold 50                                           1.521757
#
#              Nominal diff rates with clusters - False - WLS  \
# const                                                   NaN
# Agri                                              -2.005811
# Mini                                              -1.333057
# Util                                               1.247362
# M4                                               231.327895
# ...                                                     ...
# MSE Fold 46                                      263.494606
# MSE Fold 47                                      277.079653
# MSE Fold 48                                        1.527999
# MSE Fold 49                                      275.680039
# MSE Fold 50                                      269.616274
#
#              Nominal diff rates with clusters - False - PooledOLS
# const                                                      NaN
# Agri                                                  0.013881
# Mini                                                 -0.046015
# Util                                                 -0.020187
# M4                                                  -13.158373
# ...                                                        ...
# MSE Fold 46                                           1.480655
# MSE Fold 47                                           1.448818
# MSE Fold 48                                           1.423562
# MSE Fold 49                                           1.442308
# MSE Fold 50                                           1.524481
#
# [61 rows x 8 columns]

# %% [markdown]
# Now we fit the regressions and report the results that have the least mse

# %%
from abiFunctions import analyze_wls_pooled_models_least_mse

result_least_mse = analyze_wls_pooled_models_least_mse(data_cluster_dict, dependent_var='unem', k=5, shuffle=True, random_state=42, check_rank=True, num_iterations=10)
display(result_least_mse)
# Out:
#               Nominal rates with clusters - True - WLS  \
# const                                         6.677286
# Agri                                         -0.084687
# Mini                                          0.035635
# Util                                         -0.068278
# M4                                          -11.833940
# M4I                                          -9.428750
# clusters_2.0                                 -1.527420
# clusters_3.0                                 -2.398701
# clusters_4.0                                  3.002767
# $R^2$                                         0.529896
# Least MSE                                     3.956104
#
#               Nominal rates with clusters - True - PooledOLS  \
# const                                               8.332127
# Agri                                                0.029216
# Mini                                               -0.192897
# Util                                               -0.014729
# M4                                                -18.352493
# M4I                                               -53.042155
# clusters_2.0                                       -1.733684
# clusters_3.0                                       -3.306670
# clusters_4.0                                        2.770467
# $R^2$                                               0.567320
# Least MSE                                           2.940928
#
#               Nominal rates with clusters - False - WLS  \
# const                                          5.302955
# Agri                                          -0.141655
# Mini                                          -0.229305
# Util                                          -0.149344
# M4                                           -10.854977
# M4I                                          -10.704656
# clusters_2.0                                        NaN
# clusters_3.0                                        NaN
# clusters_4.0                                        NaN
# $R^2$                                          0.080092
# Least MSE                                      8.494331
#
#               Nominal rates with clusters - False - PooledOLS  \
# const                                                7.472290
# Agri                                                 0.002327
# Mini                                                -0.252101
# Util                                                -0.091964
# M4                                                 -18.718863
# M4I                                                -51.739948
# clusters_2.0                                              NaN
# clusters_3.0                                              NaN
# clusters_4.0                                              NaN
# $R^2$                                                0.171885
# Least MSE                                            5.685814
#
#               Nominal diff rates with clusters - True - WLS  \
# const                                                   NaN
# Agri                                               0.039427
# Mini                                               0.062629
# Util                                              -0.017043
# M4                                                -6.422696
# M4I                                              -20.920275
# clusters_2.0                                      -0.235328
# clusters_3.0                                      -0.032530
# clusters_4.0                                      -0.223128
# $R^2$                                              1.000000
# Least MSE                                          1.569994
#
#               Nominal diff rates with clusters - True - PooledOLS  \
# const                                                       NaN
# Agri                                                   0.018565
# Mini                                                  -0.042782
# Util                                                  -0.015188
# M4                                                   -13.411317
# M4I                                                  -40.898201
# clusters_2.0                                           0.083338
# clusters_3.0                                           0.044710
# clusters_4.0                                           0.057453
# $R^2$                                                  0.265907
# Least MSE                                              1.421589
#
#               Nominal diff rates with clusters - False - WLS  \
# const                                                    NaN
# Agri                                                0.035294
# Mini                                                0.097087
# Util                                               -0.007980
# M4                                                 -6.867179
# M4I                                               -19.847740
# clusters_2.0                                             NaN
# clusters_3.0                                             NaN
# clusters_4.0                                             NaN
# $R^2$                                               1.000000
# Least MSE                                           1.527999
#
#               Nominal diff rates with clusters - False - PooledOLS
# const                                                       NaN
# Agri                                                   0.018773
# Mini                                                  -0.044907
# Util                                                  -0.016680
# M4                                                   -13.369117
# M4I                                                  -41.262474
# clusters_2.0                                                NaN
# clusters_3.0                                                NaN
# clusters_4.0                                                NaN
# $R^2$                                                  0.264344
# Least MSE                                              1.423562

# %% [markdown]
# ## Using OLS inplace of pooledOLS

# %%
from abiFunctions import analyze_wls_ols_models_least_mse

dependent_var = 'unem'

# Analyze models
model_attributes = analyze_wls_ols_models_least_mse(data_cluster_dict, dependent_var, k=5, 
                                             shuffle=True, random_state=42, 
                                             num_iterations=10)

# Accessing results as a list
results_list = []
for attributes in model_attributes:
    results_list.append({
        'Dataset': attributes['Dataset'],
        'Clusters': attributes['Clusters'],
        'Model': attributes['Model'],
        'Beta Estimates': attributes['Beta Estimates'].values.tolist(),
        'Least MSE': attributes['Least MSE'],
        'R^2': attributes['R^2']
    })

result_df = pd.DataFrame()
for attributes in model_attributes:
    dataset_name = attributes['Dataset']
    clusters = attributes['Clusters']
    model_name = attributes['Model']
    beta_estimates = attributes['Beta Estimates']
    least_mse = attributes['Least MSE']
    r_squared = attributes['R^2']
    mse_series = pd.Series([r_squared, least_mse], index=["$R^2$", "Least MSE"])
    combined_series = pd.concat([beta_estimates, mse_series], axis=0)
    result_df = pd.concat([result_df, combined_series], axis=1)
    result_df.rename(columns={result_df.columns[-1]: f"{dataset_name} - {clusters} - {model_name}"}, inplace=True)

result_df
# Out:
#               Nominal rates with clusters - True - WLS  \
# const                                         6.677286
# Agri                                         -0.084687
# Mini                                          0.035635
# Util                                         -0.068278
# M4                                          -11.833940
# M4I                                          -9.428750
# clusters_2.0                                 -1.527420
# clusters_3.0                                 -2.398701
# clusters_4.0                                  3.002767
# $R^2$                                         0.529896
# Least MSE                                     3.956104
#
#               Nominal rates with clusters - True - OLS  \
# const                                         8.332127
# Agri                                          0.029216
# Mini                                         -0.192897
# Util                                         -0.014729
# M4                                          -18.352493
# M4I                                         -53.042155
# clusters_2.0                                 -1.733684
# clusters_3.0                                 -3.306670
# clusters_4.0                                  2.770467
# $R^2$                                         0.567320
# Least MSE                                     2.940928
#
#               Nominal rates with clusters - False - WLS  \
# const                                          5.302955
# Agri                                          -0.141655
# Mini                                          -0.229305
# Util                                          -0.149344
# M4                                           -10.854977
# M4I                                          -10.704656
# clusters_2.0                                        NaN
# clusters_3.0                                        NaN
# clusters_4.0                                        NaN
# $R^2$                                          0.080092
# Least MSE                                      8.494331
#
#               Nominal rates with clusters - False - OLS  \
# const                                          7.472290
# Agri                                           0.002327
# Mini                                          -0.252101
# Util                                          -0.091964
# M4                                           -18.718863
# M4I                                          -51.739948
# clusters_2.0                                        NaN
# clusters_3.0                                        NaN
# clusters_4.0                                        NaN
# $R^2$                                          0.171885
# Least MSE                                      5.685814
#
#               Nominal diff rates with clusters - True - WLS  \
# const                                                   NaN
# Agri                                               0.039427
# Mini                                               0.062629
# Util                                              -0.017043
# M4                                                -6.422696
# M4I                                              -20.920275
# clusters_2.0                                      -0.235328
# clusters_3.0                                      -0.032530
# clusters_4.0                                      -0.223128
# $R^2$                                              1.000000
# Least MSE                                          1.569994
#
#               Nominal diff rates with clusters - True - OLS  \
# const                                                   NaN
# Agri                                               0.018565
# Mini                                              -0.042782
# Util                                              -0.015188
# M4                                               -13.411317
# M4I                                              -40.898201
# clusters_2.0                                       0.083338
# clusters_3.0                                       0.044710
# clusters_4.0                                       0.057453
# $R^2$                                              0.265907
# Least MSE                                          1.421589
#
#               Nominal diff rates with clusters - False - WLS  \
# const                                                    NaN
# Agri                                                0.035294
# Mini                                                0.097087
# Util                                               -0.007980
# M4                                                 -6.867179
# M4I                                               -19.847740
# clusters_2.0                                             NaN
# clusters_3.0                                             NaN
# clusters_4.0                                             NaN
# $R^2$                                               1.000000
# Least MSE                                           1.527999
#
#               Nominal diff rates with clusters - False - OLS
# const                                                    NaN
# Agri                                                0.018773
# Mini                                               -0.044907
# Util                                               -0.016680
# M4                                                -13.369117
# M4I                                               -41.262474
# clusters_2.0                                             NaN
# clusters_3.0                                             NaN
# clusters_4.0                                             NaN
# $R^2$                                               0.264344
# Least MSE                                           1.423562

# %% [markdown]
# Now we create a dictionary to store the results for the regressions. This time we vary the k-folds and compare the results as k increases.

# %%
from abiFunctions import analyze_wls_ols_models_with_varying_folds

dependent_var = 'unem'

# Analyze models with varying number of folds
results_dict = analyze_wls_ols_models_with_varying_folds(data_cluster_dict, dependent_var, start_k=5, max_k=10, 
                                             shuffle=True, random_state=42, 
                                             num_iterations=10)

# %%
df_rates = results_dict['Nominal rates with clusters']

df_diff_rates = results_dict['Nominal diff rates with clusters']

# %% [markdown]
# Now we plot the results for ease of comparisons on bar charts.

# %%
from abiFunctions import plot_model_comparisons
# Plot for nominal rates with clusters
plot_model_comparisons(results_dict['Nominal rates with clusters'], 'Nominal rates')

# %%
# Plot for nominal diff rates with clusters
plot_model_comparisons(results_dict['Nominal diff rates with clusters'], 'Nominal diff rates')
