# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Generate some sample data
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', label='Predicted')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# Display the model's parameters
print(f"Intercept: {model.intercept_[0]}")
print(f"Coefficient: {model.coef_[0][0]}")
print(f"Mean Squared Error: {mse}")
# Out:
# Intercept: 4.3223585304213445
# Coefficient: 2.9364715078262478
# Mean Squared Error: 1.043433381569518

# %% [markdown]
# ### Notes on Linear Regression
#
# - **Objective**: We performed a simple linear regression to model the relationship between `X` and `y`.
# - **Data**: We used randomly generated data points with a linear relationship and some added noise.
# - **Model**: The model's equation is of the form `y = b0 + b1 * X`, where `b0` is the intercept and `b1` is the coefficient (slope).
# - **Results**:
#     - **Intercept (b0)**: The expected value of `y` when `X = 0`.
#     - **Coefficient (b1)**: The rate of change of `y` with respect to `X`.
#     - **Mean Squared Error**: This metric indicates how well the model's predictions match the actual data. A lower MSE means better accuracy.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd

# Generate some sample data
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', label='Predicted')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.savefig("regression_plot.png")  # Save the plot as an image
plt.show()

# Display the model's parameters
print(f"Intercept: {model.intercept_[0]}")
print(f"Coefficient: {model.coef_[0][0]}")
print(f"Mean Squared Error: {mse}")

# Save the results to a DataFrame
results_df = pd.DataFrame({
    "Actual": y_test.flatten(),
    "Predicted": y_pred.flatten()
})
# Out:
# Intercept: 4.3223585304213445
# Coefficient: 2.9364715078262478
# Mean Squared Error: 1.043433381569518

# %%
# Create the HTML content with a 2x2 grid for images
html_content = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Regression Report</title>
    <style>
        .grid-container {{
            display: grid;
            grid-template-columns: auto auto;
            gap: 10px;
            padding: 10px;
        }}
        .grid-item {{
            text-align: center;
            padding: 10px;
            font-size: 16px;
        }}
        img {{
            width: 100%;
            height: auto;
        }}
    </style>
</head>
<body>
    <h1>Simple Linear Regression Report</h1>
    <p><strong>Intercept:</strong> {model.intercept_[0]:.4f}</p>
    <p><strong>Coefficient:</strong> {model.coef_[0][0]:.4f}</p>
    <p><strong>Mean Squared Error:</strong> {mse:.4f}</p>
    
    <h2>Plot</h2>
    <div class="grid-container">
        <div class="grid-item">
            <img src="image1.png" alt="Image 1">
            <p>Image 1</p>
        </div>
        <div class="grid-item">
            <img src="image2.png" alt="Image 2">
            <p>Image 2</p>
        </div>
        <div class="grid-item">
            <img src="image3.png" alt="Image 3">
            <p>Image 3</p>
        </div>
        <div class="grid-item">
            <img src="image4.png" alt="Image 4">
            <p>Image 4</p>
        </div>
    </div>
    
    <h2>Actual vs Predicted</h2>
    {results_df.to_html(index=False)}
</body>
</html>
"""

# Save the HTML content to a file
with open("regression_report.html", "w") as file:
    file.write(html_content)

# %% [markdown]
# ### Notes on Linear Regression
#
# - **Objective**: We performed a simple linear regression to model the relationship between `X` and `y`.
# - **Data**: We used randomly generated data points with a linear relationship and some added noise.
# - **Model**: The model's equation is of the form `y = b0 + b1 * X`, where `b0` is the intercept and `b1` is the coefficient (slope).
# - **Results**:
#     - **Intercept (b0)**: The expected value of `y` when `X = 0`.
#     - **Coefficient (b1)**: The rate of change of `y` with respect to `X`.
#     - **Mean Squared Error**: This metric indicates how well the model's predictions match the actual data. A lower MSE means better accuracy.

# %% [markdown]
# ![Linear Regression Plot](regression_plot.png)

# %%
from IPython.display import IFrame

# Display the HTML file
display(IFrame(src="regression_report.html", width='100%', height='600px'))
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="regression_report.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
